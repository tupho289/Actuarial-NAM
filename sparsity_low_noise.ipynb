# %%
############################ 0. PREPARATION ############################

#-------------------------- import packages --------------------------
import random
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from itertools import combinations
import seaborn as sns
import copy
import itertools

import tensorflow as tf
import tensorflow_lattice as tfl
from tensorflow import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Input, Multiply, Add, Embedding, Reshape, Concatenate, Dropout, BatchNormalization, Lambda, Layer, CategoryEncoding, Activation
from keras.constraints import Constraint
from keras.callbacks import EarlyStopping
from keras.initializers import Zeros, Constant
from keras.optimizers.legacy import Adam, Nadam, RMSprop
from keras.models import clone_model
import keras_tuner as kt
from keras import backend as K
from keras import regularizers
from keras.utils import plot_model
from keras.losses import Poisson, Loss
from keras.metrics import MeanAbsoluteError, RootMeanSquaredError
from scipy.stats import gamma


from pygam import LinearGAM, GAM, s, f, l
from sklearn.linear_model import ElasticNet
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error as mae
from sklearn.tree import DecisionTreeRegressor
from interpret.glassbox import ExplainableBoostingClassifier

# %%
#-------------------------- for reproducibility --------------------------
seed_value = 2024
keras.utils.set_random_seed(seed_value)

# %%
#-------------------------- import data --------------------------
data = pd.read_csv("data/synthetic_low_var.csv")

# %%
#-------------------------- remove outliers --------------------------
log_claim = np.log(data['Y'])
IQR = log_claim.quantile(0.75) - log_claim.quantile(0.25) # inter-quartile range
lower_whisker = log_claim.quantile(0.25)- 1.5*IQR
upper_whisker = log_claim.quantile(0.75) + 1.5*IQR

# remove outliers: filter rows where the log of 'Y' is within the whiskers
dt_cleaned = data[(log_claim >= lower_whisker) & (log_claim <= upper_whisker)]
dt_cleaned
# Out:
#              X1        X2        X3        X4        X5        X6        X7  \
# 0      0.097627 -0.384709  0.070514  0.245303 -0.564460 -0.450318  0.531209
# 1      0.430379 -0.875990  0.808088  0.648436  0.174499 -0.765558 -0.898927
# 2      0.205527  0.977570  0.004793 -0.431433  0.975227  0.473320  0.995090
# 3      0.089766  0.438181 -0.798260  0.756793  0.901734  0.431272 -0.864656
# 4     -0.152690  0.515139  0.055164  0.282328 -0.314057  0.639535 -0.581069
# ...         ...       ...       ...       ...       ...       ...       ...
# 49995  0.092658  0.451842  0.805609 -0.262674  0.758215 -0.205461  0.443849
# 49996  0.386621  0.015041 -0.538708 -0.389854 -0.632906 -0.311577  0.027367
# 49997 -0.532650  0.620266  0.162028 -0.570751  0.005453  0.235543  0.099723
# 49998  0.661848  0.102065 -0.526136 -0.408447  0.373860 -0.328123  0.756798
# 49999  0.102636 -0.548488 -0.907552  0.685008 -0.631395  0.158764 -0.255068
#
#              X8        X9       X10             Y
# 0     -0.139983 -0.999956  0.009359    317.866963
# 1     -0.168761  0.081209 -0.263657     78.581657
# 2      0.794291 -0.802390 -0.861454    516.366318
# 3      0.512576  0.085770 -0.545924  17229.567290
# 4      0.940797 -0.261984 -0.425629    200.194269
# ...         ...       ...       ...           ...
# 49995 -0.978784  0.740276  0.645713     55.754110
# 49996 -0.845545  0.010439  0.868084      8.951832
# 49997  0.663875  0.851769  0.066433      9.645558
# 49998 -0.514888  0.618938  0.761628   1447.660375
# 49999 -0.854587 -0.912670 -0.468766   6162.639458
#
# [49557 rows x 11 columns]

# %%
#-------------------------- distribution of log(response) --------------------------
plt.figure(figsize = (10, 6)) # set the size of the figure
sns.set_style("darkgrid")
sns.histplot(np.log(dt_cleaned['Y']), bins = 30, kde = True) # draw the chart
plt.title('Distribution of log(Y)')
plt.xlabel('Log(Y)')
plt.ylabel('Frequency')
plt.tick_params(axis = 'x')
plt.tick_params(axis = 'y')
plt.grid(True)
plt.show()

# %%
#-------------------------- column lists --------------------------
target_var = "Y" # target feature
all_vars = list(dt_cleaned.columns)
all_vars.remove(target_var) # store all input features
cat_vars = [] # categorical features

# %%
############################ 1. MAIN EFFECT SELECTION ############################

#-------------------------- train-test split --------------------------
X_main, X_test, y_main, y_test = train_test_split(
    dt_cleaned[all_vars], dt_cleaned[["Y"]], test_size = 0.2, random_state = 1)
X_train, X_val, y_train, y_val  = train_test_split(
    X_main, y_main, test_size = 0.25, random_state = 1)

# %%
# -------------------------- function to create a subnetwork --------------------------
# subnet for numerical variables
def create_subnet(num_layers, units_first_layer, activation, model_name, dropout_rate = 0, trainable = True, seed = 1):
    model = Sequential(name = model_name)
    for i in range(num_layers):
        num_units = units_first_layer - i*int(units_first_layer/num_layers)
        model.add(Dense(num_units, activation = activation, trainable = trainable))
        model.add(Dropout(dropout_rate, seed = seed))
    model.add(Dense(1, trainable = trainable))
    model.add(BatchNormalization(scale = False)) # for identifiability
    return model

# %%
# -------------------------- custom loss function --------------------------
def gamma_nll(y_true, y_pred):
    y_pred = K.clip(y_pred, 1e-7, 1e30)
    return K.mean(y_true/y_pred - K.log(y_true/y_pred))

# %%
#-------------------------- prepare the data for NAM --------------------------
X_train_split = []
X_val_split = []
for i in range(X_train.shape[1]):
    X_train_split.append(X_train.iloc[:, i])
    X_val_split.append(X_val.iloc[:, i])

# %%
# -------------------------- Fit an ensemble of 10 NAMs --------------------------
seed = 0
num_models = 10
all_variance = []

# create ensemble and get subnet variance
for i in range(num_models):
    
    keras.utils.set_random_seed(seed)

    # -------------------------- define model architecture --------------------------
    inputs = []  # input layers
    sub_outputs_main = []  # main effect subnet output
    num_neurons_main = 20
    num_layers_main = 2
    activation = 'leaky_relu'
    keypoints = 10
    monotonicity_list = {"X3" : "decreasing"} # either "increasing", "decreasing", or "none"

    # main effect
    for name in all_vars:

        # input layer
        input_layer = Input(shape = (1,), name = name)
        inputs.append(input_layer)

        # subnetworks for main effects
        if name in cat_vars: # categorical variables
            # categorical variables will be one-hot encoded
            embed_layer = Embedding(input_dim = X_train[name].nunique(), 
                                    output_dim = 1, 
                                    name = f"{name}_embed")(input_layer)
            embed_layer_reshape = Reshape(target_shape = (1,), name = f"{name}_reshape")(embed_layer)
            mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(embed_layer_reshape)
            sub_outputs_main.append(mean_layer)
        elif name in monotonicity_list: # variables with monotonicity constraint
            calibrator_layer = tfl.layers.PWLCalibration(
                input_keypoints =  np.linspace(X_train[name].min(), X_train[name].max(), num = keypoints), # keypoints
                monotonicity = monotonicity_list[name], # monotonicity constraint
                name = f"{name}_pwlcalibrator"
            )(input_layer)
            mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(calibrator_layer)
            sub_outputs_main.append(mean_layer)
        else: # numeric variables
            subnet = create_subnet(num_layers_main, num_neurons_main, activation, f"{name}_subnetwork")
            sub_output = subnet(input_layer)
            sub_outputs_main.append(sub_output)

    # combine subnets' outputs and create model
    main_subnets = Concatenate(name = "main_subnet")(sub_outputs_main)
    final_output = Dense(1, activation = "exponential", name = "main_output")(main_subnets)
    model_all_vars = Model(inputs = inputs, outputs = final_output)

    # -------------------------- fit the model --------------------------
    model_all_vars.compile(optimizer = "adam", loss = gamma_nll, metrics = [RootMeanSquaredError(), MeanAbsoluteError()])
    es = EarlyStopping(restore_best_weights = True, patience = 10)
    model_all_vars.fit(X_train_split, y_train, epochs = 5_000, \
        callbacks = [es], batch_size = 5_000, validation_data = (X_val_split, y_val), verbose = 0)
    

    # -------------------------- quantify variable importance --------------------------
    main_output_layer = model_all_vars.get_layer("main_subnet")  # Get the subnet output layer
    main_model = Model(inputs = model_all_vars.inputs, outputs = main_output_layer.output)
    main_output_values = main_model.predict(X_train_split, batch_size = 5_000)

    # Get the variance of each subnetwork across all data points
    subnet_weights = model_all_vars.get_layer("main_output").get_weights()[0]
    subnet_variance = [np.var(main_output_values[:, i])*subnet_weights[i][0]**2 for i in range(main_output_values.shape[1])]
    all_variance.append(subnet_variance)

    # update seed
    seed += 1
# Out:
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 3ms/step

# %%
# -------------------------- plot the variable importance --------------------------
average_variances = np.mean(all_variance, axis = 0) # get the average variance

# Create DataFrame for variable importance
var_importance = pd.DataFrame({"Covariates": all_vars, "Subnet Variance": average_variances})

# Sort the DataFrame by subnet variance in decreasing order
varimp_sorted = var_importance.sort_values(by = "Subnet Variance", ascending = False)

# Create a bar plot using Seaborn
# plt.figure(figsize = (8, 6))
sns.barplot(x = "Covariates", y = "Subnet Variance", data = varimp_sorted)
plt.title("Subnet Variance - Low Noise")
plt.xlabel("")
plt.ylabel("")

plt.rcParams["figure.figsize"] = (5, 2) # (for square figures)
plt.rcParams["figure.dpi"] = 350
plt.rcParams["savefig.bbox"] = "tight"
plt.rcParams["font.family"] = "serif"
plt.rcParams["axes.spines.right"] = False
plt.rcParams["axes.spines.top"] = False

plt.show()

# %%
#-------------------------- reset keras seed --------------------------
keras.utils.set_random_seed(seed_value)

# %%
############################ 1. MODEL FITTING ############################

# extract important variables
imp_vars = [f"X{i}" for i in range(1,9)]

#-------------------------- train-test split --------------------------
X_main, X_test, y_main, y_test = train_test_split(
    dt_cleaned[imp_vars], dt_cleaned[["Y"]], test_size = 0.2, random_state = 1)
X_train, X_val, y_train, y_val  = train_test_split(
    X_main, y_main, test_size = 0.25, random_state = 1)

# %%
# -------------------------- define model architecture --------------------------
inputs = []  # input layers
sub_outputs_main = []  # main effect subnet output
num_neurons_main = 20
num_layers_main = 2
activation = 'leaky_relu'
keypoints = 10
monotonicity_list = {"X3" : "decreasing"} # either "increasing", "decreasing", or "none"

# main effect
for name in imp_vars:
    input_layer = Input(shape = (1,), name = name)
    inputs.append(input_layer)

    # subnetworks for main effects
    if name in cat_vars: # categorical variables
        # categorical variables will be one-hot encoded
        embed_layer = Embedding(input_dim = X_train[name].nunique(), 
                                output_dim = 1, 
                                name = f"{name}_embed")(input_layer)
        embed_layer_reshape = Reshape(target_shape = (1,), name = f"{name}_reshape")(embed_layer)
        mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(embed_layer_reshape)
        sub_outputs_main.append(mean_layer)
    elif name in monotonicity_list: # variables with monotonicity constraint
        calibrator_layer = tfl.layers.PWLCalibration(
            input_keypoints =  np.linspace(X_train[name].min(), X_train[name].max(), num = keypoints), # keypoints
            monotonicity = monotonicity_list[name], # monotonicity constraint
            name = f"{name}_pwlcalibrator"
        )(input_layer)
        mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(calibrator_layer)
        sub_outputs_main.append(mean_layer)
    else: # numeric variables
        subnet = create_subnet(num_layers_main, num_neurons_main, activation, f"{name}_subnetwork")
        sub_output = subnet(input_layer)
        sub_outputs_main.append(sub_output)

# combine subnets' outputs
main_subnets = Concatenate(name = "main_subnet")(sub_outputs_main)
final_output = Dense(1, activation = "exponential", name = "main_output")(main_subnets)

# final model
model_main_effect = Model(inputs = inputs, outputs = final_output)

# %%
# -------------------------- compile and fit --------------------------
# create training & validation data consistent with the model architecture
X_train_split = []
X_val_split = []
X_test_split = []
for i in range(len(X_train.columns)):
    X_train_split.append(X_train.iloc[:, i])
    X_val_split.append(X_val.iloc[:, i])
    X_test_split.append(X_test.iloc[:, i])

# compile and fit
model_main_effect.compile(optimizer = "adam", loss = gamma_nll, metrics = [RootMeanSquaredError()])
es = EarlyStopping(restore_best_weights = True, patience = 20)
# %time hist_main = model_main_effect.fit(X_train_split, y_train, epochs = 5_000, \
    callbacks = [es], batch_size = 1_000, validation_data = (X_val_split, y_val))
# Out:
# Epoch 1/5000
# 30/30 [==============================] - 1s 8ms/step - loss: 1423.3833 - root_mean_squared_error: 2690.1167 - val_loss: 636.8703 - val_root_mean_squared_error: 2589.9773
# Epoch 2/5000
# 30/30 [==============================] - 0s 2ms/step - loss: 810.0851 - root_mean_squared_error: 2690.2927 - val_loss: 651.9681 - val_root_mean_squared_error: 2589.9895
# Epoch 3/5000
# 30/30 [==============================] - 0s 2ms/step - loss: 630.0699 - root_mean_squared_error: 2690.3206 - val_loss: 581.1045 - val_root_mean_squared_error: 2589.9390
# Epoch 4/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 564.5681 - root_mean_squared_error: 2690.2717 - val_loss: 522.5515 - val_root_mean_squared_error: 2589.8872
# Epoch 5/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 506.0023 - root_mean_squared_error: 2690.2009 - val_loss: 460.7083 - val_root_mean_squared_error: 2589.8179
# Epoch 6/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 458.1840 - root_mean_squared_error: 2690.1143 - val_loss: 419.3975 - val_root_mean_squared_error: 2589.7600
# Epoch 7/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 403.2351 - root_mean_squared_error: 2690.0178 - val_loss: 377.5558 - val_root_mean_squared_error: 2589.6882
# Epoch 8/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 358.0319 - root_mean_squared_error: 2689.8992 - val_loss: 345.0362 - val_root_mean_squared_error: 2589.6204
# Epoch 9/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 316.8747 - root_mean_squared_error: 2689.7588 - val_loss: 310.6017 - val_root_mean_squared_error: 2589.5322
# Epoch 10/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 281.4983 - root_mean_squared_error: 2689.5903 - val_loss: 275.4060 - val_root_mean_squared_error: 2589.4199
# Epoch 11/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 247.3738 - root_mean_squared_error: 2689.4236 - val_loss: 250.1745 - val_root_mean_squared_error: 2589.3184
# Epoch 12/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 218.1714 - root_mean_squared_error: 2689.2224 - val_loss: 239.5893 - val_root_mean_squared_error: 2589.2637
# Epoch 13/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 191.7112 - root_mean_squared_error: 2688.9866 - val_loss: 213.1990 - val_root_mean_squared_error: 2589.1162
# Epoch 14/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 169.9934 - root_mean_squared_error: 2688.7273 - val_loss: 193.5050 - val_root_mean_squared_error: 2588.9719
# Epoch 15/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 151.2132 - root_mean_squared_error: 2688.4277 - val_loss: 167.1931 - val_root_mean_squared_error: 2588.7207
# Epoch 16/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 134.8400 - root_mean_squared_error: 2688.0688 - val_loss: 147.0026 - val_root_mean_squared_error: 2588.4734
# Epoch 17/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 120.6318 - root_mean_squared_error: 2687.7012 - val_loss: 137.1725 - val_root_mean_squared_error: 2588.2695
# Epoch 18/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 108.0118 - root_mean_squared_error: 2687.2646 - val_loss: 129.3788 - val_root_mean_squared_error: 2588.1172
# Epoch 19/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 97.1244 - root_mean_squared_error: 2686.7590 - val_loss: 106.6920 - val_root_mean_squared_error: 2587.5876
# Epoch 20/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 87.7367 - root_mean_squared_error: 2686.3452 - val_loss: 95.9213 - val_root_mean_squared_error: 2587.1194
# Epoch 21/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 79.1731 - root_mean_squared_error: 2685.7520 - val_loss: 90.6341 - val_root_mean_squared_error: 2586.8750
# Epoch 22/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 71.8327 - root_mean_squared_error: 2685.2183 - val_loss: 78.9968 - val_root_mean_squared_error: 2586.2424
# Epoch 23/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 65.1740 - root_mean_squared_error: 2684.6191 - val_loss: 74.4396 - val_root_mean_squared_error: 2585.8682
# Epoch 24/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 59.5158 - root_mean_squared_error: 2683.8840 - val_loss: 76.3165 - val_root_mean_squared_error: 2585.8193
# Epoch 25/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 54.3583 - root_mean_squared_error: 2683.1672 - val_loss: 65.0406 - val_root_mean_squared_error: 2584.8918
# Epoch 26/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 49.7706 - root_mean_squared_error: 2682.3660 - val_loss: 69.0078 - val_root_mean_squared_error: 2584.9590
# Epoch 27/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 45.8988 - root_mean_squared_error: 2681.6243 - val_loss: 58.8955 - val_root_mean_squared_error: 2583.9189
# Epoch 28/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 42.0926 - root_mean_squared_error: 2680.6733 - val_loss: 58.8941 - val_root_mean_squared_error: 2583.9902
# Epoch 29/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 38.6984 - root_mean_squared_error: 2679.7102 - val_loss: 52.2712 - val_root_mean_squared_error: 2582.8757
# Epoch 30/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 35.7871 - root_mean_squared_error: 2678.7136 - val_loss: 42.3330 - val_root_mean_squared_error: 2581.2283
# Epoch 31/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 33.1269 - root_mean_squared_error: 2677.9434 - val_loss: 33.0019 - val_root_mean_squared_error: 2578.7117
# Epoch 32/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 30.7397 - root_mean_squared_error: 2676.6453 - val_loss: 30.3733 - val_root_mean_squared_error: 2577.6475
# Epoch 33/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 28.6431 - root_mean_squared_error: 2675.6938 - val_loss: 28.3278 - val_root_mean_squared_error: 2576.5420
# Epoch 34/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 26.6861 - root_mean_squared_error: 2674.5767 - val_loss: 27.8627 - val_root_mean_squared_error: 2576.1125
# Epoch 35/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 24.9365 - root_mean_squared_error: 2673.3191 - val_loss: 25.7392 - val_root_mean_squared_error: 2574.8418
# Epoch 36/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 23.3003 - root_mean_squared_error: 2672.0159 - val_loss: 23.9046 - val_root_mean_squared_error: 2573.9646
# Epoch 37/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 21.8608 - root_mean_squared_error: 2671.0469 - val_loss: 22.9927 - val_root_mean_squared_error: 2572.7615
# Epoch 38/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 20.5729 - root_mean_squared_error: 2669.5537 - val_loss: 22.0686 - val_root_mean_squared_error: 2572.2004
# Epoch 39/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 19.3155 - root_mean_squared_error: 2668.2598 - val_loss: 20.7556 - val_root_mean_squared_error: 2570.9600
# Epoch 40/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 18.2608 - root_mean_squared_error: 2667.0837 - val_loss: 20.2515 - val_root_mean_squared_error: 2570.5730
# Epoch 41/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 17.1464 - root_mean_squared_error: 2665.5779 - val_loss: 19.8231 - val_root_mean_squared_error: 2570.2139
# Epoch 42/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 16.2216 - root_mean_squared_error: 2664.4377 - val_loss: 17.9226 - val_root_mean_squared_error: 2568.3613
# Epoch 43/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 15.3400 - root_mean_squared_error: 2662.8057 - val_loss: 18.4129 - val_root_mean_squared_error: 2569.0469
# Epoch 44/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 14.5387 - root_mean_squared_error: 2661.5610 - val_loss: 16.5689 - val_root_mean_squared_error: 2566.2698
# Epoch 45/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 13.7729 - root_mean_squared_error: 2659.9189 - val_loss: 17.3466 - val_root_mean_squared_error: 2567.5696
# Epoch 46/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 13.0641 - root_mean_squared_error: 2658.6536 - val_loss: 15.2150 - val_root_mean_squared_error: 2564.8821
# Epoch 47/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 12.3909 - root_mean_squared_error: 2656.9963 - val_loss: 14.7866 - val_root_mean_squared_error: 2563.9729
# Epoch 48/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 11.8354 - root_mean_squared_error: 2654.9863 - val_loss: 12.6368 - val_root_mean_squared_error: 2560.0942
# Epoch 49/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 11.2528 - root_mean_squared_error: 2653.9158 - val_loss: 11.0394 - val_root_mean_squared_error: 2555.3494
# Epoch 50/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 10.7280 - root_mean_squared_error: 2652.4712 - val_loss: 10.4362 - val_root_mean_squared_error: 2553.7585
# Epoch 51/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 10.2441 - root_mean_squared_error: 2650.2893 - val_loss: 10.1561 - val_root_mean_squared_error: 2552.0688
# Epoch 52/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 9.8065 - root_mean_squared_error: 2648.7559 - val_loss: 10.1245 - val_root_mean_squared_error: 2552.2183
# Epoch 53/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 9.3684 - root_mean_squared_error: 2646.6980 - val_loss: 9.8649 - val_root_mean_squared_error: 2551.0249
# Epoch 54/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 8.9854 - root_mean_squared_error: 2645.1074 - val_loss: 9.9688 - val_root_mean_squared_error: 2552.2910
# Epoch 55/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 8.6254 - root_mean_squared_error: 2643.1172 - val_loss: 9.2808 - val_root_mean_squared_error: 2549.7637
# Epoch 56/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 8.2951 - root_mean_squared_error: 2640.9104 - val_loss: 8.9132 - val_root_mean_squared_error: 2547.0181
# Epoch 57/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 7.9457 - root_mean_squared_error: 2639.1885 - val_loss: 8.0282 - val_root_mean_squared_error: 2543.4900
# Epoch 58/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 7.6564 - root_mean_squared_error: 2637.3213 - val_loss: 7.9172 - val_root_mean_squared_error: 2542.2507
# Epoch 59/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 7.3754 - root_mean_squared_error: 2635.4102 - val_loss: 7.1226 - val_root_mean_squared_error: 2536.4529
# Epoch 60/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 7.1237 - root_mean_squared_error: 2633.7090 - val_loss: 7.2597 - val_root_mean_squared_error: 2537.1628
# Epoch 61/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 6.8767 - root_mean_squared_error: 2630.1711 - val_loss: 6.8490 - val_root_mean_squared_error: 2534.5559
# Epoch 62/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 6.6360 - root_mean_squared_error: 2629.3420 - val_loss: 6.5595 - val_root_mean_squared_error: 2530.8550
# Epoch 63/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 6.4305 - root_mean_squared_error: 2625.9675 - val_loss: 6.2325 - val_root_mean_squared_error: 2528.5837
# Epoch 64/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 6.2052 - root_mean_squared_error: 2624.9895 - val_loss: 6.6703 - val_root_mean_squared_error: 2532.6670
# Epoch 65/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 6.0184 - root_mean_squared_error: 2621.8633 - val_loss: 6.5855 - val_root_mean_squared_error: 2532.6023
# Epoch 66/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 5.8295 - root_mean_squared_error: 2620.1372 - val_loss: 6.6733 - val_root_mean_squared_error: 2532.9243
# Epoch 67/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 5.6557 - root_mean_squared_error: 2617.4470 - val_loss: 6.4431 - val_root_mean_squared_error: 2530.5496
# Epoch 68/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 5.4845 - root_mean_squared_error: 2615.1777 - val_loss: 6.8926 - val_root_mean_squared_error: 2533.6094
# Epoch 69/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 5.3494 - root_mean_squared_error: 2612.5745 - val_loss: 6.8905 - val_root_mean_squared_error: 2534.6584
# Epoch 70/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 5.2007 - root_mean_squared_error: 2610.5073 - val_loss: 6.3567 - val_root_mean_squared_error: 2528.5193
# Epoch 71/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 5.0548 - root_mean_squared_error: 2607.6084 - val_loss: 6.1181 - val_root_mean_squared_error: 2527.1506
# Epoch 72/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.9261 - root_mean_squared_error: 2605.9429 - val_loss: 6.1726 - val_root_mean_squared_error: 2526.0847
# Epoch 73/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.7986 - root_mean_squared_error: 2603.0647 - val_loss: 5.7682 - val_root_mean_squared_error: 2521.7703
# Epoch 74/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.6886 - root_mean_squared_error: 2600.6104 - val_loss: 5.3957 - val_root_mean_squared_error: 2518.0364
# Epoch 75/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.5746 - root_mean_squared_error: 2597.8560 - val_loss: 5.0985 - val_root_mean_squared_error: 2513.5879
# Epoch 76/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.4760 - root_mean_squared_error: 2595.6213 - val_loss: 4.7844 - val_root_mean_squared_error: 2507.0339
# Epoch 77/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.3802 - root_mean_squared_error: 2593.0852 - val_loss: 4.5024 - val_root_mean_squared_error: 2501.6680
# Epoch 78/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.2884 - root_mean_squared_error: 2590.3005 - val_loss: 4.5347 - val_root_mean_squared_error: 2501.5923
# Epoch 79/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.1881 - root_mean_squared_error: 2587.7166 - val_loss: 4.4640 - val_root_mean_squared_error: 2500.1472
# Epoch 80/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.1150 - root_mean_squared_error: 2585.5884 - val_loss: 4.5008 - val_root_mean_squared_error: 2500.9509
# Epoch 81/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 4.0225 - root_mean_squared_error: 2582.1899 - val_loss: 4.3192 - val_root_mean_squared_error: 2497.5156
# Epoch 82/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.9459 - root_mean_squared_error: 2580.4011 - val_loss: 4.0644 - val_root_mean_squared_error: 2490.7974
# Epoch 83/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.8796 - root_mean_squared_error: 2577.6416 - val_loss: 3.8101 - val_root_mean_squared_error: 2482.5813
# Epoch 84/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.8126 - root_mean_squared_error: 2575.2610 - val_loss: 3.8581 - val_root_mean_squared_error: 2483.0911
# Epoch 85/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.7442 - root_mean_squared_error: 2572.2307 - val_loss: 3.7478 - val_root_mean_squared_error: 2480.0520
# Epoch 86/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.6865 - root_mean_squared_error: 2569.7925 - val_loss: 3.7169 - val_root_mean_squared_error: 2479.3792
# Epoch 87/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.6310 - root_mean_squared_error: 2566.5413 - val_loss: 3.6803 - val_root_mean_squared_error: 2478.2593
# Epoch 88/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.5680 - root_mean_squared_error: 2565.1663 - val_loss: 3.6003 - val_root_mean_squared_error: 2473.9829
# Epoch 89/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.5133 - root_mean_squared_error: 2561.8623 - val_loss: 3.4761 - val_root_mean_squared_error: 2469.8623
# Epoch 90/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.4657 - root_mean_squared_error: 2560.2861 - val_loss: 3.3418 - val_root_mean_squared_error: 2462.0691
# Epoch 91/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.4148 - root_mean_squared_error: 2555.6345 - val_loss: 3.3701 - val_root_mean_squared_error: 2462.7886
# Epoch 92/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.3735 - root_mean_squared_error: 2554.1931 - val_loss: 3.3670 - val_root_mean_squared_error: 2464.7283
# Epoch 93/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 3.3277 - root_mean_squared_error: 2552.2642 - val_loss: 3.2881 - val_root_mean_squared_error: 2459.6445
# Epoch 94/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.2854 - root_mean_squared_error: 2549.0525 - val_loss: 3.2598 - val_root_mean_squared_error: 2458.3279
# Epoch 95/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.2522 - root_mean_squared_error: 2547.3677 - val_loss: 3.2326 - val_root_mean_squared_error: 2456.7197
# Epoch 96/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.2064 - root_mean_squared_error: 2544.5837 - val_loss: 3.2341 - val_root_mean_squared_error: 2456.5562
# Epoch 97/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.1749 - root_mean_squared_error: 2541.9768 - val_loss: 3.2218 - val_root_mean_squared_error: 2456.0735
# Epoch 98/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.1416 - root_mean_squared_error: 2540.9641 - val_loss: 3.2037 - val_root_mean_squared_error: 2452.7859
# Epoch 99/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.1098 - root_mean_squared_error: 2537.3232 - val_loss: 3.2341 - val_root_mean_squared_error: 2456.7683
# Epoch 100/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.0805 - root_mean_squared_error: 2535.1375 - val_loss: 3.1385 - val_root_mean_squared_error: 2450.8088
# Epoch 101/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.0493 - root_mean_squared_error: 2533.3813 - val_loss: 3.0525 - val_root_mean_squared_error: 2445.5078
# Epoch 102/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.0223 - root_mean_squared_error: 2529.5806 - val_loss: 3.0184 - val_root_mean_squared_error: 2442.2971
# Epoch 103/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.9955 - root_mean_squared_error: 2529.5244 - val_loss: 3.0029 - val_root_mean_squared_error: 2441.2358
# Epoch 104/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.9683 - root_mean_squared_error: 2525.1582 - val_loss: 2.9382 - val_root_mean_squared_error: 2436.5371
# Epoch 105/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.9467 - root_mean_squared_error: 2523.8169 - val_loss: 2.9363 - val_root_mean_squared_error: 2436.1702
# Epoch 106/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.9249 - root_mean_squared_error: 2521.3462 - val_loss: 2.8635 - val_root_mean_squared_error: 2429.8582
# Epoch 107/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.9020 - root_mean_squared_error: 2519.6328 - val_loss: 2.9200 - val_root_mean_squared_error: 2435.2642
# Epoch 108/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.8828 - root_mean_squared_error: 2517.9346 - val_loss: 2.8719 - val_root_mean_squared_error: 2431.8762
# Epoch 109/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.8608 - root_mean_squared_error: 2517.9070 - val_loss: 2.8688 - val_root_mean_squared_error: 2430.7495
# Epoch 110/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.8426 - root_mean_squared_error: 2513.3301 - val_loss: 2.8542 - val_root_mean_squared_error: 2430.1257
# Epoch 111/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.8281 - root_mean_squared_error: 2512.2512 - val_loss: 2.8790 - val_root_mean_squared_error: 2432.3606
# Epoch 112/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.8075 - root_mean_squared_error: 2508.9314 - val_loss: 2.8427 - val_root_mean_squared_error: 2428.6594
# Epoch 113/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.7954 - root_mean_squared_error: 2508.5933 - val_loss: 2.8020 - val_root_mean_squared_error: 2424.6365
# Epoch 114/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.7798 - root_mean_squared_error: 2507.6682 - val_loss: 2.7809 - val_root_mean_squared_error: 2423.2202
# Epoch 115/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.7651 - root_mean_squared_error: 2504.1763 - val_loss: 2.7771 - val_root_mean_squared_error: 2423.4587
# Epoch 116/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.7509 - root_mean_squared_error: 2502.7664 - val_loss: 2.7686 - val_root_mean_squared_error: 2423.6738
# Epoch 117/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.7370 - root_mean_squared_error: 2501.7646 - val_loss: 2.7608 - val_root_mean_squared_error: 2420.8215
# Epoch 118/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.7274 - root_mean_squared_error: 2500.6384 - val_loss: 2.7553 - val_root_mean_squared_error: 2424.1897
# Epoch 119/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.7138 - root_mean_squared_error: 2499.9534 - val_loss: 2.7179 - val_root_mean_squared_error: 2417.9141
# Epoch 120/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.7057 - root_mean_squared_error: 2496.8044 - val_loss: 2.7347 - val_root_mean_squared_error: 2418.6008
# Epoch 121/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.6944 - root_mean_squared_error: 2496.4331 - val_loss: 2.7021 - val_root_mean_squared_error: 2415.3943
# Epoch 122/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6851 - root_mean_squared_error: 2495.3076 - val_loss: 2.7266 - val_root_mean_squared_error: 2420.8069
# Epoch 123/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6770 - root_mean_squared_error: 2493.2720 - val_loss: 2.7194 - val_root_mean_squared_error: 2418.8618
# Epoch 124/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6646 - root_mean_squared_error: 2492.9292 - val_loss: 2.6931 - val_root_mean_squared_error: 2412.1616
# Epoch 125/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6570 - root_mean_squared_error: 2490.6047 - val_loss: 2.6694 - val_root_mean_squared_error: 2413.0300
# Epoch 126/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6483 - root_mean_squared_error: 2491.0154 - val_loss: 2.6737 - val_root_mean_squared_error: 2414.2922
# Epoch 127/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6403 - root_mean_squared_error: 2487.0154 - val_loss: 2.6850 - val_root_mean_squared_error: 2415.2085
# Epoch 128/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6349 - root_mean_squared_error: 2488.7668 - val_loss: 2.6861 - val_root_mean_squared_error: 2412.8130
# Epoch 129/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6264 - root_mean_squared_error: 2486.9175 - val_loss: 2.6782 - val_root_mean_squared_error: 2415.2478
# Epoch 130/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6217 - root_mean_squared_error: 2485.3779 - val_loss: 2.6655 - val_root_mean_squared_error: 2414.8403
# Epoch 131/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.6190 - root_mean_squared_error: 2483.5225 - val_loss: 2.6373 - val_root_mean_squared_error: 2410.2744
# Epoch 132/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6100 - root_mean_squared_error: 2485.4260 - val_loss: 2.6617 - val_root_mean_squared_error: 2416.2092
# Epoch 133/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6057 - root_mean_squared_error: 2484.4087 - val_loss: 2.6338 - val_root_mean_squared_error: 2409.4653
# Epoch 134/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5968 - root_mean_squared_error: 2481.4670 - val_loss: 2.6311 - val_root_mean_squared_error: 2409.5342
# Epoch 135/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5946 - root_mean_squared_error: 2483.6572 - val_loss: 2.6094 - val_root_mean_squared_error: 2414.5845
# Epoch 136/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5887 - root_mean_squared_error: 2482.0691 - val_loss: 2.5917 - val_root_mean_squared_error: 2408.9783
# Epoch 137/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5851 - root_mean_squared_error: 2480.0127 - val_loss: 2.6076 - val_root_mean_squared_error: 2409.1919
# Epoch 138/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5802 - root_mean_squared_error: 2478.8354 - val_loss: 2.5979 - val_root_mean_squared_error: 2406.9160
# Epoch 139/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5762 - root_mean_squared_error: 2479.9158 - val_loss: 2.5983 - val_root_mean_squared_error: 2408.5623
# Epoch 140/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5723 - root_mean_squared_error: 2479.5461 - val_loss: 2.5964 - val_root_mean_squared_error: 2411.5835
# Epoch 141/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5696 - root_mean_squared_error: 2478.7771 - val_loss: 2.5967 - val_root_mean_squared_error: 2409.5437
# Epoch 142/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5672 - root_mean_squared_error: 2476.3811 - val_loss: 2.5767 - val_root_mean_squared_error: 2407.4365
# Epoch 143/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5634 - root_mean_squared_error: 2477.9675 - val_loss: 2.5850 - val_root_mean_squared_error: 2411.1831
# Epoch 144/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5620 - root_mean_squared_error: 2480.2876 - val_loss: 2.6062 - val_root_mean_squared_error: 2414.9966
# Epoch 145/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5591 - root_mean_squared_error: 2477.6731 - val_loss: 2.5920 - val_root_mean_squared_error: 2404.2190
# Epoch 146/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5568 - root_mean_squared_error: 2479.5664 - val_loss: 2.5969 - val_root_mean_squared_error: 2407.4714
# Epoch 147/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5538 - root_mean_squared_error: 2477.5369 - val_loss: 2.5904 - val_root_mean_squared_error: 2406.6780
# Epoch 148/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5525 - root_mean_squared_error: 2476.1482 - val_loss: 2.5996 - val_root_mean_squared_error: 2411.4211
# Epoch 149/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5502 - root_mean_squared_error: 2478.3970 - val_loss: 2.5723 - val_root_mean_squared_error: 2407.4543
# Epoch 150/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5492 - root_mean_squared_error: 2479.2446 - val_loss: 2.5785 - val_root_mean_squared_error: 2418.3669
# Epoch 151/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5479 - root_mean_squared_error: 2479.1174 - val_loss: 2.5792 - val_root_mean_squared_error: 2437.3989
# Epoch 152/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5455 - root_mean_squared_error: 2477.0298 - val_loss: 2.5685 - val_root_mean_squared_error: 2423.9758
# Epoch 153/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5429 - root_mean_squared_error: 2476.1326 - val_loss: 2.5639 - val_root_mean_squared_error: 2413.6165
# Epoch 154/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5422 - root_mean_squared_error: 2477.0730 - val_loss: 2.5679 - val_root_mean_squared_error: 2424.9861
# Epoch 155/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5428 - root_mean_squared_error: 2479.4539 - val_loss: 2.5666 - val_root_mean_squared_error: 2413.6736
# Epoch 156/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5412 - root_mean_squared_error: 2475.8679 - val_loss: 2.5627 - val_root_mean_squared_error: 2421.5537
# Epoch 157/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5395 - root_mean_squared_error: 2477.4941 - val_loss: 2.5594 - val_root_mean_squared_error: 2421.2878
# Epoch 158/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5389 - root_mean_squared_error: 2477.3652 - val_loss: 2.5696 - val_root_mean_squared_error: 2413.8298
# Epoch 159/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5393 - root_mean_squared_error: 2478.8733 - val_loss: 2.5720 - val_root_mean_squared_error: 2423.2437
# Epoch 160/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5374 - root_mean_squared_error: 2479.2949 - val_loss: 2.5691 - val_root_mean_squared_error: 2412.2722
# Epoch 161/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5349 - root_mean_squared_error: 2479.9351 - val_loss: 2.5695 - val_root_mean_squared_error: 2405.1582
# Epoch 162/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5386 - root_mean_squared_error: 2475.4553 - val_loss: 2.5748 - val_root_mean_squared_error: 2409.7041
# Epoch 163/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5341 - root_mean_squared_error: 2480.4172 - val_loss: 2.5708 - val_root_mean_squared_error: 2412.3174
# Epoch 164/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5337 - root_mean_squared_error: 2481.3054 - val_loss: 2.5775 - val_root_mean_squared_error: 2422.6426
# Epoch 165/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5344 - root_mean_squared_error: 2477.7920 - val_loss: 2.5690 - val_root_mean_squared_error: 2414.6272
# Epoch 166/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5314 - root_mean_squared_error: 2479.4407 - val_loss: 2.5700 - val_root_mean_squared_error: 2421.3577
# Epoch 167/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5314 - root_mean_squared_error: 2480.9353 - val_loss: 2.5704 - val_root_mean_squared_error: 2411.2395
# Epoch 168/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5309 - root_mean_squared_error: 2479.4736 - val_loss: 2.5646 - val_root_mean_squared_error: 2414.0959
# Epoch 169/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5319 - root_mean_squared_error: 2475.7756 - val_loss: 2.5808 - val_root_mean_squared_error: 2424.7634
# Epoch 170/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5307 - root_mean_squared_error: 2482.2612 - val_loss: 2.5679 - val_root_mean_squared_error: 2413.4543
# Epoch 171/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5312 - root_mean_squared_error: 2481.4529 - val_loss: 2.5738 - val_root_mean_squared_error: 2419.6812
# Epoch 172/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5283 - root_mean_squared_error: 2478.2959 - val_loss: 2.5716 - val_root_mean_squared_error: 2414.0645
# Epoch 173/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5293 - root_mean_squared_error: 2478.3960 - val_loss: 2.5758 - val_root_mean_squared_error: 2410.2590
# Epoch 174/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5302 - root_mean_squared_error: 2480.3120 - val_loss: 2.5634 - val_root_mean_squared_error: 2413.1106
# Epoch 175/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5301 - root_mean_squared_error: 2481.9688 - val_loss: 2.5635 - val_root_mean_squared_error: 2418.3235
# Epoch 176/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5298 - root_mean_squared_error: 2479.8918 - val_loss: 2.5664 - val_root_mean_squared_error: 2431.9763
# Epoch 177/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5293 - root_mean_squared_error: 2481.1201 - val_loss: 2.5674 - val_root_mean_squared_error: 2422.8184
# CPU times: user 19.7 s, sys: 3.66 s, total: 23.4 s
# Wall time: 18.5 s

# %%
# -------------------------- get validation loss --------------------------
main_val_loss, main_rmse = model_main_effect.evaluate(X_val_split, y_val, verbose = False) # get the validation loss and RMSE
print(f"Validation loss for main effect: {main_val_loss}")
print(f"Validation RMSE for main effect: {main_rmse}")
# Out:
# Validation loss for main effect: 2.5594444274902344
# Validation RMSE for main effect: 2421.287841796875

# %%
############################   preparation for interaction selection   ############################
global_layers = ["main_subnet", "main_output", "interaction_output", "final_output"] # these layers are always trainable
imp_vars = [f"X{i}" for i in range(1,9)] # important variables
num_layers_interaction = 10 # number of layers for each interaction effect
num_neurons_interaction = 100 # number of neurons per dense layer for each interaction effect
keypoints = 20
lattice_sizes_pairwise = {}
for var in imp_vars:
    if var in cat_vars:
        lattice_sizes_pairwise[var] = X_train[var].nunique()
    else:
        lattice_sizes_pairwise[var] = 8

# %%
# -------------------------- create calibrator for lattice layer --------------------------
def add_calibrate_layer(var, data, monotonicity_list, lattice_sizes, keypoints, cat_vars, lattice_smooth_reg = [0,0]):
    if var in cat_vars:
        calibrator_layer = tfl.layers.CategoricalCalibration(
            num_buckets = data[var].nunique(),
            output_min = 0,
            output_max = lattice_sizes[var] - 1,
            name = f"{var}_calibrator_pairwise"
        )
    else:
        calibrator_layer = tfl.layers.PWLCalibration(
            input_keypoints =  np.linspace(data[var].min(), data[var].max(), num = keypoints), # keypoints
            kernel_regularizer = ('hessian', lattice_smooth_reg[0], lattice_smooth_reg[1]), # for smoothness
            monotonicity = monotonicity_list[var] if var in monotonicity_list else "none", # monotonicity constraint
            output_min = 0,
            output_max = lattice_sizes[var] - 1,
            name = f"{var}_calibrator_pairwise"
            )
    return calibrator_layer

# %%
############################ select interaction effect ############################

interactions = combinations(imp_vars, 2)
interaction_loss = {} # this stores the validation loss when fitting each pair of interaction effect
for var1, var2 in interactions:

    # -------------------------- initialize a cloned model --------------------------
    model_main_cloned = clone_model(model_main_effect) # clone the main effect model
    model_main_cloned.build(model_main_effect.input_shape)
    model_main_cloned.set_weights(model_main_effect.get_weights()) # copy the weights


    # -------------------------- build a subnet for pairwise interaction effect --------------------------
    var1_input = model_main_cloned.inputs[imp_vars.index(var1)]
    var2_input = model_main_cloned.inputs[imp_vars.index(var2)]

    # Lattice model if the pair contains a monotonic variable
    if any(var in monotonicity_list for var in [var1, var2]):
        lattice_inputs = []

        # create calibrator_layer
        calibrator_var1 = add_calibrate_layer(var1, X_train, monotonicity_list, lattice_sizes_pairwise, keypoints, cat_vars)
        calibrator_var2 = add_calibrate_layer(var2, X_train, monotonicity_list, lattice_sizes_pairwise, keypoints, cat_vars)
        calibrator_layer_var1 = calibrator_var1(var1_input)
        calibrator_layer_var2 = calibrator_var2(var2_input)
        
        # lattice
        lattice_inputs.append(calibrator_layer_var1)
        lattice_inputs.append(calibrator_layer_var2)
        lattice_layer = tfl.layers.Lattice(lattice_sizes = [lattice_sizes_pairwise[var1],lattice_sizes_pairwise[var2]], 
                            monotonicities = ["increasing" if var1 in monotonicity_list else 'none',
                                                "increasing" if var2 in monotonicity_list else 'none'],
                            name = f"{var1}_{var2}_lattice")(lattice_inputs)
        pairwise_output = BatchNormalization(scale = False, name = f"{var1}_{var2}_mean")(lattice_layer)
    else:
        # Subnetwork if the pair contains no monotonic variables
        pairwise_input_layer = Concatenate(name = f"{var1}_{var2}_concat")([var1_input, var2_input])
        pairwise_subnet = create_subnet(num_layers_interaction, 
                                        num_neurons_interaction, 
                                        activation, 
                                        f"{var1}_{var2}_subnetwork")
        pairwise_output = pairwise_subnet(pairwise_input_layer)

    # final output
    interaction_subnet_output = Activation('exponential',
                        name = "interaction_output")(pairwise_output)
    main_subnet_output = model_main_cloned.output
    final_output = Multiply(name = "final_output")([main_subnet_output, interaction_subnet_output])
    model_pairwise = Model(inputs = model_main_cloned.inputs, outputs = final_output)


    # -------------------------- switch on/off layers --------------------------
    for layer in model_pairwise.layers:
        if layer.name not in global_layers and var1 not in layer.name and var2 not in layer.name:
            layer.trainable = False

    # -------------------------- compile and train the model --------------------------
    model_pairwise.compile(optimizer = 'adam', 
                        loss = gamma_nll, 
                        metrics = [gamma_nll, RootMeanSquaredError()])
    es = EarlyStopping(patience = 25, restore_best_weights = True)
    model_pairwise.fit(X_train_split, y_train, epochs = 5_000, \
                            callbacks = [es], batch_size = 1_000, validation_data = (X_val_split, y_val))
    _, gamma_log_metric, _ = model_pairwise.evaluate(X_val_split, y_val, batch_size = X_val_split[0].shape[0])
    interaction_loss[f"{var1}_{var2}"] = gamma_log_metric # add to the val loss list
# Out:
# Epoch 1/5000
# 30/30 [==============================] - 1s 13ms/step - loss: 2.5406 - gamma_nll: 2.5408 - root_mean_squared_error: 2490.5469 - val_loss: 2.5707 - val_gamma_nll: 2.5707 - val_root_mean_squared_error: 2433.8369
# Epoch 2/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5369 - gamma_nll: 2.5366 - root_mean_squared_error: 2509.8333 - val_loss: 2.6260 - val_gamma_nll: 2.6259 - val_root_mean_squared_error: 2409.5969
# Epoch 3/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5289 - gamma_nll: 2.5306 - root_mean_squared_error: 2496.5022 - val_loss: 2.6415 - val_gamma_nll: 2.6414 - val_root_mean_squared_error: 2408.7983
# Epoch 4/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5334 - gamma_nll: 2.5343 - root_mean_squared_error: 2504.4473 - val_loss: 2.6195 - val_gamma_nll: 2.6193 - val_root_mean_squared_error: 2409.1987
# Epoch 5/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5295 - gamma_nll: 2.5294 - root_mean_squared_error: 2496.0759 - val_loss: 2.5945 - val_gamma_nll: 2.5944 - val_root_mean_squared_error: 2503.3059
# Epoch 6/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5314 - gamma_nll: 2.5325 - root_mean_squared_error: 2502.3240 - val_loss: 2.5840 - val_gamma_nll: 2.5840 - val_root_mean_squared_error: 2423.5898
# Epoch 7/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5384 - gamma_nll: 2.5386 - root_mean_squared_error: 2509.3479 - val_loss: 2.5748 - val_gamma_nll: 2.5747 - val_root_mean_squared_error: 2466.9783
# Epoch 8/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5305 - gamma_nll: 2.5305 - root_mean_squared_error: 2503.6399 - val_loss: 2.5898 - val_gamma_nll: 2.5897 - val_root_mean_squared_error: 2512.1379
# Epoch 9/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5267 - gamma_nll: 2.5260 - root_mean_squared_error: 2495.6750 - val_loss: 2.5880 - val_gamma_nll: 2.5879 - val_root_mean_squared_error: 2530.0444
# Epoch 10/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5273 - gamma_nll: 2.5268 - root_mean_squared_error: 2497.1462 - val_loss: 2.5693 - val_gamma_nll: 2.5693 - val_root_mean_squared_error: 2445.7090
# Epoch 11/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5313 - gamma_nll: 2.5313 - root_mean_squared_error: 2507.4333 - val_loss: 2.5785 - val_gamma_nll: 2.5784 - val_root_mean_squared_error: 2494.3132
# Epoch 12/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5296 - gamma_nll: 2.5297 - root_mean_squared_error: 2497.7488 - val_loss: 2.5659 - val_gamma_nll: 2.5658 - val_root_mean_squared_error: 2416.8704
# Epoch 13/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5292 - gamma_nll: 2.5298 - root_mean_squared_error: 2497.0654 - val_loss: 2.5612 - val_gamma_nll: 2.5612 - val_root_mean_squared_error: 2423.8079
# Epoch 14/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5310 - gamma_nll: 2.5319 - root_mean_squared_error: 2500.5334 - val_loss: 2.5881 - val_gamma_nll: 2.5881 - val_root_mean_squared_error: 2492.9746
# Epoch 15/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5303 - gamma_nll: 2.5311 - root_mean_squared_error: 2499.9626 - val_loss: 2.5649 - val_gamma_nll: 2.5648 - val_root_mean_squared_error: 2460.5266
# Epoch 16/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5292 - gamma_nll: 2.5291 - root_mean_squared_error: 2499.5149 - val_loss: 2.5631 - val_gamma_nll: 2.5631 - val_root_mean_squared_error: 2429.5613
# Epoch 17/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5302 - gamma_nll: 2.5310 - root_mean_squared_error: 2496.9727 - val_loss: 2.5754 - val_gamma_nll: 2.5754 - val_root_mean_squared_error: 2482.4111
# Epoch 18/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5313 - gamma_nll: 2.5313 - root_mean_squared_error: 2501.1011 - val_loss: 2.5684 - val_gamma_nll: 2.5684 - val_root_mean_squared_error: 2437.6978
# Epoch 19/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5265 - gamma_nll: 2.5261 - root_mean_squared_error: 2497.7546 - val_loss: 2.5842 - val_gamma_nll: 2.5840 - val_root_mean_squared_error: 2424.3022
# Epoch 20/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5317 - gamma_nll: 2.5312 - root_mean_squared_error: 2499.6304 - val_loss: 2.5860 - val_gamma_nll: 2.5857 - val_root_mean_squared_error: 2418.4856
# Epoch 21/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5266 - gamma_nll: 2.5262 - root_mean_squared_error: 2496.1550 - val_loss: 2.5974 - val_gamma_nll: 2.5971 - val_root_mean_squared_error: 2415.2551
# Epoch 22/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5270 - gamma_nll: 2.5269 - root_mean_squared_error: 2500.8945 - val_loss: 2.5750 - val_gamma_nll: 2.5749 - val_root_mean_squared_error: 2479.8652
# Epoch 23/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5287 - gamma_nll: 2.5287 - root_mean_squared_error: 2496.3989 - val_loss: 2.5706 - val_gamma_nll: 2.5705 - val_root_mean_squared_error: 2473.4814
# Epoch 24/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5268 - gamma_nll: 2.5268 - root_mean_squared_error: 2496.1421 - val_loss: 2.5739 - val_gamma_nll: 2.5739 - val_root_mean_squared_error: 2433.7622
# Epoch 25/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5359 - gamma_nll: 2.5367 - root_mean_squared_error: 2512.1038 - val_loss: 2.6535 - val_gamma_nll: 2.6533 - val_root_mean_squared_error: 2785.6157
# Epoch 26/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5315 - gamma_nll: 2.5305 - root_mean_squared_error: 2507.5740 - val_loss: 3.0380 - val_gamma_nll: 3.0381 - val_root_mean_squared_error: 3871.6753
# Epoch 27/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5290 - gamma_nll: 2.5294 - root_mean_squared_error: 2496.9290 - val_loss: 2.8196 - val_gamma_nll: 2.8195 - val_root_mean_squared_error: 3139.0205
# Epoch 28/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5297 - gamma_nll: 2.5288 - root_mean_squared_error: 2495.1138 - val_loss: 2.6955 - val_gamma_nll: 2.6954 - val_root_mean_squared_error: 2820.9644
# Epoch 29/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5263 - gamma_nll: 2.5261 - root_mean_squared_error: 2497.9453 - val_loss: 2.5631 - val_gamma_nll: 2.5630 - val_root_mean_squared_error: 2445.0134
# Epoch 30/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5283 - gamma_nll: 2.5279 - root_mean_squared_error: 2500.1584 - val_loss: 2.5811 - val_gamma_nll: 2.5809 - val_root_mean_squared_error: 2413.1218
# Epoch 31/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5327 - gamma_nll: 2.5330 - root_mean_squared_error: 2503.6880 - val_loss: 2.5698 - val_gamma_nll: 2.5696 - val_root_mean_squared_error: 2456.7693
# Epoch 32/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5340 - gamma_nll: 2.5340 - root_mean_squared_error: 2505.4180 - val_loss: 2.5873 - val_gamma_nll: 2.5870 - val_root_mean_squared_error: 2489.4756
# Epoch 33/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5324 - gamma_nll: 2.5328 - root_mean_squared_error: 2504.0911 - val_loss: 2.5686 - val_gamma_nll: 2.5684 - val_root_mean_squared_error: 2424.6929
# Epoch 34/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5289 - gamma_nll: 2.5273 - root_mean_squared_error: 2496.2900 - val_loss: 2.5788 - val_gamma_nll: 2.5786 - val_root_mean_squared_error: 2437.1272
# Epoch 35/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5261 - gamma_nll: 2.5252 - root_mean_squared_error: 2499.3328 - val_loss: 2.5710 - val_gamma_nll: 2.5708 - val_root_mean_squared_error: 2427.8472
# Epoch 36/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5256 - gamma_nll: 2.5254 - root_mean_squared_error: 2498.3682 - val_loss: 2.5695 - val_gamma_nll: 2.5693 - val_root_mean_squared_error: 2413.3711
# Epoch 37/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5293 - gamma_nll: 2.5285 - root_mean_squared_error: 2496.6719 - val_loss: 2.6320 - val_gamma_nll: 2.6316 - val_root_mean_squared_error: 2435.7412
# Epoch 38/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5288 - gamma_nll: 2.5291 - root_mean_squared_error: 2504.7361 - val_loss: 2.6261 - val_gamma_nll: 2.6258 - val_root_mean_squared_error: 2412.1965
# 1/1 [==============================] - 0s 23ms/step - loss: 2.5612 - gamma_nll: 2.5612 - root_mean_squared_error: 2423.8079
# Epoch 1/5000
# 30/30 [==============================] - 1s 10ms/step - loss: 2.3719 - gamma_nll: 2.3717 - root_mean_squared_error: 2442.5295 - val_loss: 2.7673 - val_gamma_nll: 2.7673 - val_root_mean_squared_error: 2905.0557
# Epoch 2/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3608 - gamma_nll: 2.3605 - root_mean_squared_error: 2434.0381 - val_loss: 2.5967 - val_gamma_nll: 2.5966 - val_root_mean_squared_error: 2519.4175
# Epoch 3/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3577 - gamma_nll: 2.3587 - root_mean_squared_error: 2425.9219 - val_loss: 2.5438 - val_gamma_nll: 2.5437 - val_root_mean_squared_error: 2426.0271
# Epoch 4/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3592 - gamma_nll: 2.3596 - root_mean_squared_error: 2434.6909 - val_loss: 2.5174 - val_gamma_nll: 2.5173 - val_root_mean_squared_error: 2407.0471
# Epoch 5/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3540 - gamma_nll: 2.3531 - root_mean_squared_error: 2425.9829 - val_loss: 2.4916 - val_gamma_nll: 2.4917 - val_root_mean_squared_error: 2454.3999
# Epoch 6/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3567 - gamma_nll: 2.3567 - root_mean_squared_error: 2435.2329 - val_loss: 2.4537 - val_gamma_nll: 2.4539 - val_root_mean_squared_error: 2414.8206
# Epoch 7/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3585 - gamma_nll: 2.3587 - root_mean_squared_error: 2431.0137 - val_loss: 2.5087 - val_gamma_nll: 2.5087 - val_root_mean_squared_error: 2481.4832
# Epoch 8/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3620 - gamma_nll: 2.3625 - root_mean_squared_error: 2443.9026 - val_loss: 2.4737 - val_gamma_nll: 2.4738 - val_root_mean_squared_error: 2413.4111
# Epoch 9/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3587 - gamma_nll: 2.3582 - root_mean_squared_error: 2433.1599 - val_loss: 2.4359 - val_gamma_nll: 2.4362 - val_root_mean_squared_error: 2478.8416
# Epoch 10/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3600 - gamma_nll: 2.3597 - root_mean_squared_error: 2443.7581 - val_loss: 2.4782 - val_gamma_nll: 2.4784 - val_root_mean_squared_error: 2565.6501
# Epoch 11/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3581 - gamma_nll: 2.3581 - root_mean_squared_error: 2434.4214 - val_loss: 2.3832 - val_gamma_nll: 2.3837 - val_root_mean_squared_error: 2456.6809
# Epoch 12/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3603 - gamma_nll: 2.3603 - root_mean_squared_error: 2442.0654 - val_loss: 2.4481 - val_gamma_nll: 2.4484 - val_root_mean_squared_error: 2470.4136
# Epoch 13/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3539 - gamma_nll: 2.3546 - root_mean_squared_error: 2435.4509 - val_loss: 2.4377 - val_gamma_nll: 2.4380 - val_root_mean_squared_error: 2497.5205
# Epoch 14/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3555 - gamma_nll: 2.3557 - root_mean_squared_error: 2437.2197 - val_loss: 2.4072 - val_gamma_nll: 2.4077 - val_root_mean_squared_error: 2491.5618
# Epoch 15/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3553 - gamma_nll: 2.3561 - root_mean_squared_error: 2438.3416 - val_loss: 2.4211 - val_gamma_nll: 2.4215 - val_root_mean_squared_error: 2544.4731
# Epoch 16/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3560 - gamma_nll: 2.3556 - root_mean_squared_error: 2442.8616 - val_loss: 2.3816 - val_gamma_nll: 2.3822 - val_root_mean_squared_error: 2417.9548
# Epoch 17/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3562 - gamma_nll: 2.3575 - root_mean_squared_error: 2434.3911 - val_loss: 2.4058 - val_gamma_nll: 2.4067 - val_root_mean_squared_error: 2397.4983
# Epoch 18/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3544 - gamma_nll: 2.3541 - root_mean_squared_error: 2436.5996 - val_loss: 2.4295 - val_gamma_nll: 2.4303 - val_root_mean_squared_error: 2371.1594
# Epoch 19/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3520 - gamma_nll: 2.3518 - root_mean_squared_error: 2430.0950 - val_loss: 2.4012 - val_gamma_nll: 2.4018 - val_root_mean_squared_error: 2375.9436
# Epoch 20/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3528 - gamma_nll: 2.3524 - root_mean_squared_error: 2435.4075 - val_loss: 2.4021 - val_gamma_nll: 2.4028 - val_root_mean_squared_error: 2392.9558
# Epoch 21/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3531 - gamma_nll: 2.3527 - root_mean_squared_error: 2438.3831 - val_loss: 2.4510 - val_gamma_nll: 2.4518 - val_root_mean_squared_error: 2389.8281
# Epoch 22/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3540 - gamma_nll: 2.3537 - root_mean_squared_error: 2446.8103 - val_loss: 2.3754 - val_gamma_nll: 2.3759 - val_root_mean_squared_error: 2388.6528
# Epoch 23/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3535 - gamma_nll: 2.3540 - root_mean_squared_error: 2429.4924 - val_loss: 2.3701 - val_gamma_nll: 2.3707 - val_root_mean_squared_error: 2417.5652
# Epoch 24/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3536 - gamma_nll: 2.3536 - root_mean_squared_error: 2438.4119 - val_loss: 2.3874 - val_gamma_nll: 2.3881 - val_root_mean_squared_error: 2483.6599
# Epoch 25/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3559 - gamma_nll: 2.3570 - root_mean_squared_error: 2440.5500 - val_loss: 2.4250 - val_gamma_nll: 2.4258 - val_root_mean_squared_error: 2428.0833
# Epoch 26/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3554 - gamma_nll: 2.3550 - root_mean_squared_error: 2440.7961 - val_loss: 2.4476 - val_gamma_nll: 2.4483 - val_root_mean_squared_error: 2371.3489
# Epoch 27/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3559 - gamma_nll: 2.3556 - root_mean_squared_error: 2433.7581 - val_loss: 2.3797 - val_gamma_nll: 2.3804 - val_root_mean_squared_error: 2417.2075
# Epoch 28/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3531 - gamma_nll: 2.3516 - root_mean_squared_error: 2439.7532 - val_loss: 2.3941 - val_gamma_nll: 2.3950 - val_root_mean_squared_error: 2403.1626
# Epoch 29/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3521 - gamma_nll: 2.3517 - root_mean_squared_error: 2441.5513 - val_loss: 2.3760 - val_gamma_nll: 2.3766 - val_root_mean_squared_error: 2399.0303
# Epoch 30/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3550 - gamma_nll: 2.3557 - root_mean_squared_error: 2440.1489 - val_loss: 2.3783 - val_gamma_nll: 2.3789 - val_root_mean_squared_error: 2390.9380
# Epoch 31/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3568 - gamma_nll: 2.3568 - root_mean_squared_error: 2442.9397 - val_loss: 2.3995 - val_gamma_nll: 2.4004 - val_root_mean_squared_error: 2402.8635
# Epoch 32/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3514 - gamma_nll: 2.3511 - root_mean_squared_error: 2440.1516 - val_loss: 2.4024 - val_gamma_nll: 2.4028 - val_root_mean_squared_error: 2490.8723
# Epoch 33/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3521 - gamma_nll: 2.3513 - root_mean_squared_error: 2439.2903 - val_loss: 2.3699 - val_gamma_nll: 2.3706 - val_root_mean_squared_error: 2432.4688
# Epoch 34/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3533 - gamma_nll: 2.3521 - root_mean_squared_error: 2443.1113 - val_loss: 2.3771 - val_gamma_nll: 2.3776 - val_root_mean_squared_error: 2392.5798
# Epoch 35/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3548 - gamma_nll: 2.3542 - root_mean_squared_error: 2440.7849 - val_loss: 2.3752 - val_gamma_nll: 2.3758 - val_root_mean_squared_error: 2417.0725
# Epoch 36/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3505 - gamma_nll: 2.3512 - root_mean_squared_error: 2443.9490 - val_loss: 2.3987 - val_gamma_nll: 2.3994 - val_root_mean_squared_error: 2374.5557
# Epoch 37/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3510 - gamma_nll: 2.3512 - root_mean_squared_error: 2440.2302 - val_loss: 2.4901 - val_gamma_nll: 2.4908 - val_root_mean_squared_error: 2385.9839
# Epoch 38/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3529 - gamma_nll: 2.3528 - root_mean_squared_error: 2438.3826 - val_loss: 2.5988 - val_gamma_nll: 2.5997 - val_root_mean_squared_error: 2384.1816
# Epoch 39/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3510 - gamma_nll: 2.3503 - root_mean_squared_error: 2444.3789 - val_loss: 2.4064 - val_gamma_nll: 2.4073 - val_root_mean_squared_error: 2390.0334
# Epoch 40/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3511 - gamma_nll: 2.3520 - root_mean_squared_error: 2442.3660 - val_loss: 2.3849 - val_gamma_nll: 2.3855 - val_root_mean_squared_error: 2386.2522
# Epoch 41/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3502 - gamma_nll: 2.3513 - root_mean_squared_error: 2440.8972 - val_loss: 2.3985 - val_gamma_nll: 2.3990 - val_root_mean_squared_error: 2509.0779
# Epoch 42/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3511 - gamma_nll: 2.3506 - root_mean_squared_error: 2444.4763 - val_loss: 2.4387 - val_gamma_nll: 2.4392 - val_root_mean_squared_error: 2775.7153
# Epoch 43/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3533 - gamma_nll: 2.3541 - root_mean_squared_error: 2451.5303 - val_loss: 2.4618 - val_gamma_nll: 2.4621 - val_root_mean_squared_error: 2717.5034
# Epoch 44/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3514 - gamma_nll: 2.3520 - root_mean_squared_error: 2442.1614 - val_loss: 2.3737 - val_gamma_nll: 2.3742 - val_root_mean_squared_error: 2469.9302
# Epoch 45/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3499 - gamma_nll: 2.3498 - root_mean_squared_error: 2443.4185 - val_loss: 2.3973 - val_gamma_nll: 2.3978 - val_root_mean_squared_error: 2567.6577
# Epoch 46/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3512 - gamma_nll: 2.3513 - root_mean_squared_error: 2447.3169 - val_loss: 2.4138 - val_gamma_nll: 2.4144 - val_root_mean_squared_error: 2751.5488
# Epoch 47/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3547 - gamma_nll: 2.3554 - root_mean_squared_error: 2451.6895 - val_loss: 2.4624 - val_gamma_nll: 2.4628 - val_root_mean_squared_error: 2742.2812
# Epoch 48/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3536 - gamma_nll: 2.3539 - root_mean_squared_error: 2454.6648 - val_loss: 2.3752 - val_gamma_nll: 2.3758 - val_root_mean_squared_error: 2467.9954
# Epoch 49/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3503 - gamma_nll: 2.3512 - root_mean_squared_error: 2444.6750 - val_loss: 2.3716 - val_gamma_nll: 2.3722 - val_root_mean_squared_error: 2432.5029
# Epoch 50/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3527 - gamma_nll: 2.3527 - root_mean_squared_error: 2442.2080 - val_loss: 2.4331 - val_gamma_nll: 2.4341 - val_root_mean_squared_error: 2477.0110
# Epoch 51/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3567 - gamma_nll: 2.3558 - root_mean_squared_error: 2460.7786 - val_loss: 2.4483 - val_gamma_nll: 2.4487 - val_root_mean_squared_error: 2660.1045
# Epoch 52/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3515 - gamma_nll: 2.3512 - root_mean_squared_error: 2447.2593 - val_loss: 2.4467 - val_gamma_nll: 2.4473 - val_root_mean_squared_error: 2855.9424
# Epoch 53/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3501 - gamma_nll: 2.3499 - root_mean_squared_error: 2442.7478 - val_loss: 2.4333 - val_gamma_nll: 2.4338 - val_root_mean_squared_error: 2647.2300
# Epoch 54/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3519 - gamma_nll: 2.3512 - root_mean_squared_error: 2450.7585 - val_loss: 2.3989 - val_gamma_nll: 2.3994 - val_root_mean_squared_error: 2571.1484
# Epoch 55/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3563 - gamma_nll: 2.3571 - root_mean_squared_error: 2453.0020 - val_loss: 2.3739 - val_gamma_nll: 2.3746 - val_root_mean_squared_error: 2470.1917
# Epoch 56/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3552 - gamma_nll: 2.3561 - root_mean_squared_error: 2465.4707 - val_loss: 2.3792 - val_gamma_nll: 2.3800 - val_root_mean_squared_error: 2414.7048
# Epoch 57/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3513 - gamma_nll: 2.3511 - root_mean_squared_error: 2444.5195 - val_loss: 2.4436 - val_gamma_nll: 2.4440 - val_root_mean_squared_error: 2673.8132
# Epoch 58/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3599 - gamma_nll: 2.3600 - root_mean_squared_error: 2451.7520 - val_loss: 2.3856 - val_gamma_nll: 2.3861 - val_root_mean_squared_error: 2555.3894
# 1/1 [==============================] - 0s 17ms/step - loss: 2.3699 - gamma_nll: 2.3699 - root_mean_squared_error: 2432.4685
# Epoch 1/5000
# 30/30 [==============================] - 1s 13ms/step - loss: 2.5487 - gamma_nll: 2.5491 - root_mean_squared_error: 2501.7847 - val_loss: 2.5668 - val_gamma_nll: 2.5668 - val_root_mean_squared_error: 2468.3904
# Epoch 2/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5347 - gamma_nll: 2.5346 - root_mean_squared_error: 2509.9670 - val_loss: 2.5722 - val_gamma_nll: 2.5721 - val_root_mean_squared_error: 2463.6929
# Epoch 3/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5287 - gamma_nll: 2.5305 - root_mean_squared_error: 2499.6060 - val_loss: 2.5899 - val_gamma_nll: 2.5899 - val_root_mean_squared_error: 2511.4277
# Epoch 4/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5343 - gamma_nll: 2.5351 - root_mean_squared_error: 2505.7637 - val_loss: 2.6141 - val_gamma_nll: 2.6141 - val_root_mean_squared_error: 2546.9719
# Epoch 5/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5306 - gamma_nll: 2.5304 - root_mean_squared_error: 2499.9692 - val_loss: 2.5892 - val_gamma_nll: 2.5892 - val_root_mean_squared_error: 2542.3362
# Epoch 6/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5298 - gamma_nll: 2.5308 - root_mean_squared_error: 2499.2051 - val_loss: 2.5687 - val_gamma_nll: 2.5686 - val_root_mean_squared_error: 2478.6064
# Epoch 7/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5315 - gamma_nll: 2.5316 - root_mean_squared_error: 2500.4758 - val_loss: 2.6183 - val_gamma_nll: 2.6183 - val_root_mean_squared_error: 2620.2346
# Epoch 8/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5309 - gamma_nll: 2.5310 - root_mean_squared_error: 2501.0938 - val_loss: 2.5998 - val_gamma_nll: 2.5998 - val_root_mean_squared_error: 2527.8086
# Epoch 9/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5294 - gamma_nll: 2.5287 - root_mean_squared_error: 2498.6460 - val_loss: 2.5705 - val_gamma_nll: 2.5703 - val_root_mean_squared_error: 2424.0752
# Epoch 10/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5275 - gamma_nll: 2.5270 - root_mean_squared_error: 2499.4856 - val_loss: 2.5876 - val_gamma_nll: 2.5875 - val_root_mean_squared_error: 2428.5417
# Epoch 11/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5314 - gamma_nll: 2.5316 - root_mean_squared_error: 2507.2109 - val_loss: 2.6161 - val_gamma_nll: 2.6158 - val_root_mean_squared_error: 2451.5791
# Epoch 12/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5309 - gamma_nll: 2.5309 - root_mean_squared_error: 2500.1379 - val_loss: 2.5709 - val_gamma_nll: 2.5708 - val_root_mean_squared_error: 2423.0520
# Epoch 13/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5258 - gamma_nll: 2.5266 - root_mean_squared_error: 2496.0300 - val_loss: 2.5856 - val_gamma_nll: 2.5857 - val_root_mean_squared_error: 2496.3679
# Epoch 14/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5291 - gamma_nll: 2.5300 - root_mean_squared_error: 2503.8777 - val_loss: 2.5947 - val_gamma_nll: 2.5947 - val_root_mean_squared_error: 2514.3301
# Epoch 15/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5302 - gamma_nll: 2.5309 - root_mean_squared_error: 2501.6670 - val_loss: 2.5905 - val_gamma_nll: 2.5905 - val_root_mean_squared_error: 2520.4346
# Epoch 16/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5291 - gamma_nll: 2.5291 - root_mean_squared_error: 2500.6338 - val_loss: 2.5824 - val_gamma_nll: 2.5824 - val_root_mean_squared_error: 2494.7148
# Epoch 17/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5292 - gamma_nll: 2.5300 - root_mean_squared_error: 2498.8008 - val_loss: 2.6176 - val_gamma_nll: 2.6176 - val_root_mean_squared_error: 2585.3997
# Epoch 18/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5320 - gamma_nll: 2.5321 - root_mean_squared_error: 2501.0154 - val_loss: 2.5751 - val_gamma_nll: 2.5751 - val_root_mean_squared_error: 2479.3633
# Epoch 19/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5282 - gamma_nll: 2.5279 - root_mean_squared_error: 2500.0234 - val_loss: 2.5670 - val_gamma_nll: 2.5669 - val_root_mean_squared_error: 2423.5613
# Epoch 20/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5295 - gamma_nll: 2.5289 - root_mean_squared_error: 2501.6860 - val_loss: 2.6051 - val_gamma_nll: 2.6050 - val_root_mean_squared_error: 2417.0068
# Epoch 21/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5285 - gamma_nll: 2.5281 - root_mean_squared_error: 2500.2502 - val_loss: 2.6551 - val_gamma_nll: 2.6548 - val_root_mean_squared_error: 2413.3772
# Epoch 22/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5288 - gamma_nll: 2.5287 - root_mean_squared_error: 2504.8003 - val_loss: 2.6261 - val_gamma_nll: 2.6260 - val_root_mean_squared_error: 2409.6033
# Epoch 23/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5269 - gamma_nll: 2.5269 - root_mean_squared_error: 2496.9912 - val_loss: 2.6627 - val_gamma_nll: 2.6625 - val_root_mean_squared_error: 2413.4839
# Epoch 24/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5266 - gamma_nll: 2.5267 - root_mean_squared_error: 2501.6594 - val_loss: 2.6133 - val_gamma_nll: 2.6133 - val_root_mean_squared_error: 2412.8958
# Epoch 25/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5323 - gamma_nll: 2.5329 - root_mean_squared_error: 2505.5129 - val_loss: 2.5744 - val_gamma_nll: 2.5742 - val_root_mean_squared_error: 2444.5288
# Epoch 26/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5317 - gamma_nll: 2.5308 - root_mean_squared_error: 2504.5024 - val_loss: 2.5669 - val_gamma_nll: 2.5668 - val_root_mean_squared_error: 2427.8376
# 1/1 [==============================] - 0s 27ms/step - loss: 2.5668 - gamma_nll: 2.5668 - root_mean_squared_error: 2468.3904
# Epoch 1/5000
# 30/30 [==============================] - 1s 13ms/step - loss: 2.5415 - gamma_nll: 2.5416 - root_mean_squared_error: 2500.2104 - val_loss: 2.6017 - val_gamma_nll: 2.6017 - val_root_mean_squared_error: 2555.3835
# Epoch 2/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5315 - gamma_nll: 2.5314 - root_mean_squared_error: 2504.7754 - val_loss: 2.5977 - val_gamma_nll: 2.5977 - val_root_mean_squared_error: 2578.2000
# Epoch 3/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5319 - gamma_nll: 2.5336 - root_mean_squared_error: 2504.5432 - val_loss: 2.5649 - val_gamma_nll: 2.5647 - val_root_mean_squared_error: 2443.2722
# Epoch 4/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5384 - gamma_nll: 2.5393 - root_mean_squared_error: 2517.6897 - val_loss: 2.6300 - val_gamma_nll: 2.6299 - val_root_mean_squared_error: 2403.3953
# Epoch 5/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5345 - gamma_nll: 2.5342 - root_mean_squared_error: 2507.0361 - val_loss: 2.7029 - val_gamma_nll: 2.7027 - val_root_mean_squared_error: 2410.6418
# Epoch 6/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5316 - gamma_nll: 2.5325 - root_mean_squared_error: 2503.3850 - val_loss: 2.6076 - val_gamma_nll: 2.6075 - val_root_mean_squared_error: 2424.4419
# Epoch 7/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5286 - gamma_nll: 2.5287 - root_mean_squared_error: 2494.7729 - val_loss: 2.5788 - val_gamma_nll: 2.5786 - val_root_mean_squared_error: 2500.1704
# Epoch 8/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5283 - gamma_nll: 2.5283 - root_mean_squared_error: 2501.7458 - val_loss: 2.5693 - val_gamma_nll: 2.5692 - val_root_mean_squared_error: 2448.9612
# Epoch 9/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5298 - gamma_nll: 2.5290 - root_mean_squared_error: 2499.7300 - val_loss: 2.5675 - val_gamma_nll: 2.5674 - val_root_mean_squared_error: 2449.9895
# Epoch 10/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5256 - gamma_nll: 2.5251 - root_mean_squared_error: 2496.4138 - val_loss: 2.5683 - val_gamma_nll: 2.5682 - val_root_mean_squared_error: 2467.7749
# Epoch 11/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5281 - gamma_nll: 2.5281 - root_mean_squared_error: 2497.4817 - val_loss: 2.6018 - val_gamma_nll: 2.6017 - val_root_mean_squared_error: 2563.9587
# Epoch 12/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5294 - gamma_nll: 2.5294 - root_mean_squared_error: 2497.6892 - val_loss: 2.5883 - val_gamma_nll: 2.5883 - val_root_mean_squared_error: 2533.8950
# Epoch 13/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5264 - gamma_nll: 2.5272 - root_mean_squared_error: 2494.9441 - val_loss: 2.5893 - val_gamma_nll: 2.5893 - val_root_mean_squared_error: 2489.8665
# Epoch 14/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5250 - gamma_nll: 2.5257 - root_mean_squared_error: 2495.0959 - val_loss: 2.5627 - val_gamma_nll: 2.5627 - val_root_mean_squared_error: 2451.0708
# Epoch 15/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5275 - gamma_nll: 2.5283 - root_mean_squared_error: 2489.8320 - val_loss: 2.5639 - val_gamma_nll: 2.5638 - val_root_mean_squared_error: 2463.2300
# Epoch 16/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5276 - gamma_nll: 2.5277 - root_mean_squared_error: 2502.5144 - val_loss: 2.5891 - val_gamma_nll: 2.5889 - val_root_mean_squared_error: 2427.3940
# Epoch 17/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5262 - gamma_nll: 2.5269 - root_mean_squared_error: 2491.7146 - val_loss: 2.7790 - val_gamma_nll: 2.7789 - val_root_mean_squared_error: 2423.9331
# Epoch 18/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5291 - gamma_nll: 2.5291 - root_mean_squared_error: 2500.9365 - val_loss: 2.6511 - val_gamma_nll: 2.6511 - val_root_mean_squared_error: 2405.4663
# Epoch 19/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5237 - gamma_nll: 2.5234 - root_mean_squared_error: 2492.3311 - val_loss: 2.7173 - val_gamma_nll: 2.7171 - val_root_mean_squared_error: 2416.1216
# Epoch 20/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5295 - gamma_nll: 2.5291 - root_mean_squared_error: 2495.8679 - val_loss: 2.5669 - val_gamma_nll: 2.5668 - val_root_mean_squared_error: 2407.3147
# Epoch 21/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5305 - gamma_nll: 2.5300 - root_mean_squared_error: 2500.2952 - val_loss: 2.5593 - val_gamma_nll: 2.5592 - val_root_mean_squared_error: 2418.5688
# Epoch 22/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5252 - gamma_nll: 2.5249 - root_mean_squared_error: 2505.9524 - val_loss: 2.5620 - val_gamma_nll: 2.5620 - val_root_mean_squared_error: 2395.5430
# Epoch 23/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5278 - gamma_nll: 2.5277 - root_mean_squared_error: 2494.6216 - val_loss: 2.5886 - val_gamma_nll: 2.5884 - val_root_mean_squared_error: 2452.7349
# Epoch 24/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5257 - gamma_nll: 2.5258 - root_mean_squared_error: 2494.9705 - val_loss: 2.5690 - val_gamma_nll: 2.5690 - val_root_mean_squared_error: 2459.1870
# Epoch 25/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5282 - gamma_nll: 2.5289 - root_mean_squared_error: 2501.8508 - val_loss: 2.6481 - val_gamma_nll: 2.6481 - val_root_mean_squared_error: 2710.8921
# Epoch 26/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5282 - gamma_nll: 2.5273 - root_mean_squared_error: 2496.8354 - val_loss: 2.5863 - val_gamma_nll: 2.5863 - val_root_mean_squared_error: 2500.4924
# Epoch 27/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5282 - gamma_nll: 2.5284 - root_mean_squared_error: 2495.3579 - val_loss: 2.5706 - val_gamma_nll: 2.5704 - val_root_mean_squared_error: 2440.7112
# Epoch 28/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5284 - gamma_nll: 2.5274 - root_mean_squared_error: 2492.2776 - val_loss: 2.5661 - val_gamma_nll: 2.5660 - val_root_mean_squared_error: 2478.2837
# Epoch 29/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5265 - gamma_nll: 2.5261 - root_mean_squared_error: 2502.8027 - val_loss: 2.5560 - val_gamma_nll: 2.5559 - val_root_mean_squared_error: 2426.5747
# Epoch 30/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5304 - gamma_nll: 2.5300 - root_mean_squared_error: 2498.0093 - val_loss: 2.5934 - val_gamma_nll: 2.5935 - val_root_mean_squared_error: 2487.0710
# Epoch 31/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5311 - gamma_nll: 2.5314 - root_mean_squared_error: 2504.1458 - val_loss: 2.6470 - val_gamma_nll: 2.6470 - val_root_mean_squared_error: 2611.6558
# Epoch 32/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5357 - gamma_nll: 2.5357 - root_mean_squared_error: 2513.7424 - val_loss: 2.6768 - val_gamma_nll: 2.6768 - val_root_mean_squared_error: 2742.9780
# Epoch 33/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5288 - gamma_nll: 2.5288 - root_mean_squared_error: 2499.2561 - val_loss: 2.6070 - val_gamma_nll: 2.6070 - val_root_mean_squared_error: 2566.2986
# Epoch 34/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5254 - gamma_nll: 2.5238 - root_mean_squared_error: 2492.9780 - val_loss: 2.7185 - val_gamma_nll: 2.7185 - val_root_mean_squared_error: 2822.9255
# Epoch 35/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5224 - gamma_nll: 2.5216 - root_mean_squared_error: 2492.4109 - val_loss: 2.6634 - val_gamma_nll: 2.6635 - val_root_mean_squared_error: 2690.2751
# Epoch 36/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5273 - gamma_nll: 2.5271 - root_mean_squared_error: 2496.4189 - val_loss: 2.6078 - val_gamma_nll: 2.6077 - val_root_mean_squared_error: 2581.5718
# Epoch 37/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5299 - gamma_nll: 2.5291 - root_mean_squared_error: 2493.7229 - val_loss: 2.6258 - val_gamma_nll: 2.6257 - val_root_mean_squared_error: 2642.9639
# Epoch 38/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5273 - gamma_nll: 2.5277 - root_mean_squared_error: 2500.5583 - val_loss: 2.6354 - val_gamma_nll: 2.6354 - val_root_mean_squared_error: 2589.4766
# Epoch 39/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5260 - gamma_nll: 2.5253 - root_mean_squared_error: 2496.1216 - val_loss: 2.5954 - val_gamma_nll: 2.5954 - val_root_mean_squared_error: 2544.4568
# Epoch 40/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5325 - gamma_nll: 2.5324 - root_mean_squared_error: 2509.7922 - val_loss: 2.5788 - val_gamma_nll: 2.5786 - val_root_mean_squared_error: 2417.5063
# Epoch 41/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5307 - gamma_nll: 2.5312 - root_mean_squared_error: 2498.3862 - val_loss: 2.5737 - val_gamma_nll: 2.5736 - val_root_mean_squared_error: 2488.4861
# Epoch 42/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5226 - gamma_nll: 2.5226 - root_mean_squared_error: 2494.2666 - val_loss: 2.6164 - val_gamma_nll: 2.6163 - val_root_mean_squared_error: 2607.5217
# Epoch 43/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5256 - gamma_nll: 2.5266 - root_mean_squared_error: 2497.7349 - val_loss: 2.6742 - val_gamma_nll: 2.6742 - val_root_mean_squared_error: 2699.0447
# Epoch 44/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5237 - gamma_nll: 2.5239 - root_mean_squared_error: 2493.4592 - val_loss: 2.6901 - val_gamma_nll: 2.6901 - val_root_mean_squared_error: 2835.8271
# Epoch 45/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5229 - gamma_nll: 2.5235 - root_mean_squared_error: 2492.0632 - val_loss: 2.6677 - val_gamma_nll: 2.6677 - val_root_mean_squared_error: 2686.4907
# Epoch 46/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5238 - gamma_nll: 2.5246 - root_mean_squared_error: 2490.1145 - val_loss: 2.5894 - val_gamma_nll: 2.5894 - val_root_mean_squared_error: 2568.3728
# Epoch 47/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5284 - gamma_nll: 2.5287 - root_mean_squared_error: 2499.0244 - val_loss: 2.5716 - val_gamma_nll: 2.5715 - val_root_mean_squared_error: 2470.3982
# Epoch 48/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5285 - gamma_nll: 2.5290 - root_mean_squared_error: 2500.7283 - val_loss: 2.5751 - val_gamma_nll: 2.5751 - val_root_mean_squared_error: 2483.3147
# Epoch 49/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5275 - gamma_nll: 2.5281 - root_mean_squared_error: 2501.5010 - val_loss: 2.5607 - val_gamma_nll: 2.5607 - val_root_mean_squared_error: 2436.2036
# Epoch 50/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5262 - gamma_nll: 2.5257 - root_mean_squared_error: 2493.3811 - val_loss: 2.5785 - val_gamma_nll: 2.5785 - val_root_mean_squared_error: 2491.5291
# Epoch 51/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5327 - gamma_nll: 2.5310 - root_mean_squared_error: 2500.6641 - val_loss: 2.6153 - val_gamma_nll: 2.6152 - val_root_mean_squared_error: 2674.0330
# Epoch 52/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5340 - gamma_nll: 2.5337 - root_mean_squared_error: 2512.2512 - val_loss: 2.6092 - val_gamma_nll: 2.6091 - val_root_mean_squared_error: 2621.9602
# Epoch 53/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5282 - gamma_nll: 2.5274 - root_mean_squared_error: 2496.8062 - val_loss: 2.5827 - val_gamma_nll: 2.5827 - val_root_mean_squared_error: 2545.5503
# Epoch 54/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5218 - gamma_nll: 2.5210 - root_mean_squared_error: 2496.4160 - val_loss: 2.5881 - val_gamma_nll: 2.5881 - val_root_mean_squared_error: 2551.8774
# 1/1 [==============================] - 0s 24ms/step - loss: 2.5560 - gamma_nll: 2.5560 - root_mean_squared_error: 2426.5747
# Epoch 1/5000
# 30/30 [==============================] - 1s 13ms/step - loss: 2.5397 - gamma_nll: 2.5398 - root_mean_squared_error: 2490.1204 - val_loss: 2.5649 - val_gamma_nll: 2.5648 - val_root_mean_squared_error: 2424.9260
# Epoch 2/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5298 - gamma_nll: 2.5297 - root_mean_squared_error: 2496.8013 - val_loss: 2.5726 - val_gamma_nll: 2.5724 - val_root_mean_squared_error: 2417.8245
# Epoch 3/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5289 - gamma_nll: 2.5305 - root_mean_squared_error: 2491.7935 - val_loss: 2.5629 - val_gamma_nll: 2.5628 - val_root_mean_squared_error: 2417.4209
# Epoch 4/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5337 - gamma_nll: 2.5345 - root_mean_squared_error: 2499.6956 - val_loss: 2.5647 - val_gamma_nll: 2.5646 - val_root_mean_squared_error: 2410.7009
# Epoch 5/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5298 - gamma_nll: 2.5295 - root_mean_squared_error: 2491.7195 - val_loss: 2.5724 - val_gamma_nll: 2.5723 - val_root_mean_squared_error: 2443.5925
# Epoch 6/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5284 - gamma_nll: 2.5295 - root_mean_squared_error: 2492.2515 - val_loss: 2.5841 - val_gamma_nll: 2.5840 - val_root_mean_squared_error: 2433.2710
# Epoch 7/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5289 - gamma_nll: 2.5290 - root_mean_squared_error: 2491.9380 - val_loss: 2.5743 - val_gamma_nll: 2.5742 - val_root_mean_squared_error: 2453.1792
# Epoch 8/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5299 - gamma_nll: 2.5300 - root_mean_squared_error: 2490.4792 - val_loss: 2.5675 - val_gamma_nll: 2.5674 - val_root_mean_squared_error: 2451.7720
# Epoch 9/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5272 - gamma_nll: 2.5266 - root_mean_squared_error: 2493.2778 - val_loss: 2.5708 - val_gamma_nll: 2.5707 - val_root_mean_squared_error: 2441.4409
# Epoch 10/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5284 - gamma_nll: 2.5279 - root_mean_squared_error: 2490.1101 - val_loss: 2.6112 - val_gamma_nll: 2.6110 - val_root_mean_squared_error: 2415.1814
# Epoch 11/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5285 - gamma_nll: 2.5286 - root_mean_squared_error: 2495.8652 - val_loss: 2.6354 - val_gamma_nll: 2.6350 - val_root_mean_squared_error: 2441.3171
# Epoch 12/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5285 - gamma_nll: 2.5285 - root_mean_squared_error: 2490.6799 - val_loss: 2.6393 - val_gamma_nll: 2.6391 - val_root_mean_squared_error: 2414.6362
# Epoch 13/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5259 - gamma_nll: 2.5267 - root_mean_squared_error: 2489.1714 - val_loss: 2.6187 - val_gamma_nll: 2.6186 - val_root_mean_squared_error: 2408.9355
# Epoch 14/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5266 - gamma_nll: 2.5274 - root_mean_squared_error: 2494.0901 - val_loss: 2.5809 - val_gamma_nll: 2.5808 - val_root_mean_squared_error: 2409.9114
# Epoch 15/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5290 - gamma_nll: 2.5299 - root_mean_squared_error: 2493.1458 - val_loss: 2.6443 - val_gamma_nll: 2.6441 - val_root_mean_squared_error: 2424.6184
# Epoch 16/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5293 - gamma_nll: 2.5293 - root_mean_squared_error: 2491.9646 - val_loss: 2.6125 - val_gamma_nll: 2.6124 - val_root_mean_squared_error: 2415.5884
# Epoch 17/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5288 - gamma_nll: 2.5295 - root_mean_squared_error: 2492.4734 - val_loss: 2.6057 - val_gamma_nll: 2.6057 - val_root_mean_squared_error: 2415.4336
# Epoch 18/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5275 - gamma_nll: 2.5276 - root_mean_squared_error: 2491.6045 - val_loss: 2.5845 - val_gamma_nll: 2.5845 - val_root_mean_squared_error: 2418.2659
# Epoch 19/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5268 - gamma_nll: 2.5266 - root_mean_squared_error: 2492.0862 - val_loss: 2.5859 - val_gamma_nll: 2.5858 - val_root_mean_squared_error: 2415.4529
# Epoch 20/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5277 - gamma_nll: 2.5272 - root_mean_squared_error: 2494.0952 - val_loss: 2.5640 - val_gamma_nll: 2.5639 - val_root_mean_squared_error: 2424.0044
# Epoch 21/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5272 - gamma_nll: 2.5267 - root_mean_squared_error: 2491.4985 - val_loss: 2.5834 - val_gamma_nll: 2.5832 - val_root_mean_squared_error: 2410.6094
# Epoch 22/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5283 - gamma_nll: 2.5282 - root_mean_squared_error: 2501.3970 - val_loss: 2.5613 - val_gamma_nll: 2.5613 - val_root_mean_squared_error: 2432.6851
# Epoch 23/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5317 - gamma_nll: 2.5317 - root_mean_squared_error: 2497.6221 - val_loss: 2.5650 - val_gamma_nll: 2.5650 - val_root_mean_squared_error: 2454.1621
# Epoch 24/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5263 - gamma_nll: 2.5264 - root_mean_squared_error: 2495.0601 - val_loss: 2.5704 - val_gamma_nll: 2.5704 - val_root_mean_squared_error: 2440.9402
# Epoch 25/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5322 - gamma_nll: 2.5329 - root_mean_squared_error: 2496.1287 - val_loss: 2.5716 - val_gamma_nll: 2.5715 - val_root_mean_squared_error: 2467.0911
# Epoch 26/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5320 - gamma_nll: 2.5312 - root_mean_squared_error: 2494.7317 - val_loss: 2.5861 - val_gamma_nll: 2.5860 - val_root_mean_squared_error: 2409.9680
# Epoch 27/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5277 - gamma_nll: 2.5280 - root_mean_squared_error: 2493.7947 - val_loss: 2.5721 - val_gamma_nll: 2.5720 - val_root_mean_squared_error: 2425.8491
# Epoch 28/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5306 - gamma_nll: 2.5296 - root_mean_squared_error: 2492.7336 - val_loss: 2.5704 - val_gamma_nll: 2.5703 - val_root_mean_squared_error: 2431.0869
# Epoch 29/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5260 - gamma_nll: 2.5258 - root_mean_squared_error: 2493.1113 - val_loss: 2.5950 - val_gamma_nll: 2.5949 - val_root_mean_squared_error: 2416.7197
# Epoch 30/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5273 - gamma_nll: 2.5269 - root_mean_squared_error: 2496.8232 - val_loss: 2.6721 - val_gamma_nll: 2.6720 - val_root_mean_squared_error: 2410.8003
# Epoch 31/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5320 - gamma_nll: 2.5324 - root_mean_squared_error: 2497.5674 - val_loss: 2.6178 - val_gamma_nll: 2.6176 - val_root_mean_squared_error: 2419.5371
# Epoch 32/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5318 - gamma_nll: 2.5321 - root_mean_squared_error: 2500.3594 - val_loss: 2.6085 - val_gamma_nll: 2.6083 - val_root_mean_squared_error: 2410.5210
# Epoch 33/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5285 - gamma_nll: 2.5288 - root_mean_squared_error: 2493.5063 - val_loss: 2.6649 - val_gamma_nll: 2.6647 - val_root_mean_squared_error: 2415.6621
# Epoch 34/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5278 - gamma_nll: 2.5262 - root_mean_squared_error: 2492.0466 - val_loss: 2.6254 - val_gamma_nll: 2.6252 - val_root_mean_squared_error: 2414.0574
# Epoch 35/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5286 - gamma_nll: 2.5278 - root_mean_squared_error: 2498.3577 - val_loss: 2.5946 - val_gamma_nll: 2.5945 - val_root_mean_squared_error: 2406.4653
# Epoch 36/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5260 - gamma_nll: 2.5259 - root_mean_squared_error: 2493.4290 - val_loss: 2.6338 - val_gamma_nll: 2.6337 - val_root_mean_squared_error: 2405.9944
# Epoch 37/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5290 - gamma_nll: 2.5283 - root_mean_squared_error: 2493.1111 - val_loss: 2.7273 - val_gamma_nll: 2.7269 - val_root_mean_squared_error: 2425.5415
# Epoch 38/5000
# ...
# Epoch 55/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.3329 - gamma_nll: 2.3330 - root_mean_squared_error: 2421.3081 - val_loss: 2.3902 - val_gamma_nll: 2.3898 - val_root_mean_squared_error: 2356.9578
# Epoch 56/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.3349 - gamma_nll: 2.3360 - root_mean_squared_error: 2423.3257 - val_loss: 2.3646 - val_gamma_nll: 2.3644 - val_root_mean_squared_error: 2327.4297
# Epoch 57/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.3305 - gamma_nll: 2.3303 - root_mean_squared_error: 2425.8247 - val_loss: 2.3778 - val_gamma_nll: 2.3776 - val_root_mean_squared_error: 2355.1091
# Epoch 58/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.3232 - gamma_nll: 2.3237 - root_mean_squared_error: 2414.2866 - val_loss: 2.4257 - val_gamma_nll: 2.4254 - val_root_mean_squared_error: 2343.0186
# Epoch 59/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.3401 - gamma_nll: 2.3406 - root_mean_squared_error: 2420.7993 - val_loss: 2.3650 - val_gamma_nll: 2.3649 - val_root_mean_squared_error: 2328.1865
# Epoch 60/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.3255 - gamma_nll: 2.3253 - root_mean_squared_error: 2430.5007 - val_loss: 2.3900 - val_gamma_nll: 2.3900 - val_root_mean_squared_error: 2355.1064
# Epoch 61/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.3203 - gamma_nll: 2.3215 - root_mean_squared_error: 2423.5874 - val_loss: 2.3960 - val_gamma_nll: 2.3957 - val_root_mean_squared_error: 2422.1465
# Epoch 62/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.3270 - gamma_nll: 2.3255 - root_mean_squared_error: 2408.6611 - val_loss: 2.3409 - val_gamma_nll: 2.3408 - val_root_mean_squared_error: 2340.2627
# Epoch 63/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.3205 - gamma_nll: 2.3210 - root_mean_squared_error: 2410.9153 - val_loss: 2.3597 - val_gamma_nll: 2.3596 - val_root_mean_squared_error: 2405.5039
# Epoch 64/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.3349 - gamma_nll: 2.3353 - root_mean_squared_error: 2421.8530 - val_loss: 2.3983 - val_gamma_nll: 2.3980 - val_root_mean_squared_error: 2439.0615
# Epoch 65/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.3170 - gamma_nll: 2.3169 - root_mean_squared_error: 2412.4014 - val_loss: 2.3843 - val_gamma_nll: 2.3841 - val_root_mean_squared_error: 2369.0569
# Epoch 66/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.3346 - gamma_nll: 2.3352 - root_mean_squared_error: 2414.9709 - val_loss: 2.3769 - val_gamma_nll: 2.3767 - val_root_mean_squared_error: 2363.5051
# Epoch 67/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.3121 - gamma_nll: 2.3127 - root_mean_squared_error: 2409.4282 - val_loss: 2.3704 - val_gamma_nll: 2.3703 - val_root_mean_squared_error: 2368.0144
# Epoch 68/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.3183 - gamma_nll: 2.3174 - root_mean_squared_error: 2414.6160 - val_loss: 2.4048 - val_gamma_nll: 2.4046 - val_root_mean_squared_error: 2357.8320
# Epoch 69/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.3049 - gamma_nll: 2.3048 - root_mean_squared_error: 2408.7610 - val_loss: 2.4086 - val_gamma_nll: 2.4088 - val_root_mean_squared_error: 2337.6030
# Epoch 70/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2985 - gamma_nll: 2.2993 - root_mean_squared_error: 2422.8784 - val_loss: 2.4040 - val_gamma_nll: 2.4039 - val_root_mean_squared_error: 2342.2542
# Epoch 71/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.3006 - gamma_nll: 2.3004 - root_mean_squared_error: 2405.1631 - val_loss: 2.3785 - val_gamma_nll: 2.3785 - val_root_mean_squared_error: 2333.8906
# Epoch 72/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.3123 - gamma_nll: 2.3133 - root_mean_squared_error: 2415.6321 - val_loss: 2.3574 - val_gamma_nll: 2.3571 - val_root_mean_squared_error: 2399.5061
# Epoch 73/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2969 - gamma_nll: 2.2966 - root_mean_squared_error: 2413.9922 - val_loss: 2.3611 - val_gamma_nll: 2.3614 - val_root_mean_squared_error: 2351.2505
# Epoch 74/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.3031 - gamma_nll: 2.3027 - root_mean_squared_error: 2414.8442 - val_loss: 2.3751 - val_gamma_nll: 2.3748 - val_root_mean_squared_error: 2429.3154
# Epoch 75/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.3007 - gamma_nll: 2.2999 - root_mean_squared_error: 2406.5046 - val_loss: 2.3518 - val_gamma_nll: 2.3516 - val_root_mean_squared_error: 2433.0232
# Epoch 76/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2935 - gamma_nll: 2.2933 - root_mean_squared_error: 2406.1309 - val_loss: 2.3692 - val_gamma_nll: 2.3691 - val_root_mean_squared_error: 2417.0579
# Epoch 77/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.2924 - gamma_nll: 2.2927 - root_mean_squared_error: 2412.4771 - val_loss: 2.3251 - val_gamma_nll: 2.3249 - val_root_mean_squared_error: 2353.2766
# Epoch 78/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.3026 - gamma_nll: 2.3026 - root_mean_squared_error: 2417.4185 - val_loss: 2.3372 - val_gamma_nll: 2.3374 - val_root_mean_squared_error: 2344.4531
# Epoch 79/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2926 - gamma_nll: 2.2926 - root_mean_squared_error: 2410.8440 - val_loss: 2.3755 - val_gamma_nll: 2.3756 - val_root_mean_squared_error: 2458.3599
# Epoch 80/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.3001 - gamma_nll: 2.3007 - root_mean_squared_error: 2420.1179 - val_loss: 2.3633 - val_gamma_nll: 2.3632 - val_root_mean_squared_error: 2447.7549
# Epoch 81/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2862 - gamma_nll: 2.2870 - root_mean_squared_error: 2400.5439 - val_loss: 2.4203 - val_gamma_nll: 2.4202 - val_root_mean_squared_error: 2597.9517
# Epoch 82/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.2783 - gamma_nll: 2.2774 - root_mean_squared_error: 2405.5422 - val_loss: 2.3445 - val_gamma_nll: 2.3446 - val_root_mean_squared_error: 2394.2239
# Epoch 83/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2866 - gamma_nll: 2.2867 - root_mean_squared_error: 2408.4714 - val_loss: 2.3882 - val_gamma_nll: 2.3881 - val_root_mean_squared_error: 2553.7068
# Epoch 84/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.2937 - gamma_nll: 2.2944 - root_mean_squared_error: 2411.4868 - val_loss: 2.3605 - val_gamma_nll: 2.3603 - val_root_mean_squared_error: 2451.0032
# Epoch 85/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.2948 - gamma_nll: 2.2946 - root_mean_squared_error: 2412.2856 - val_loss: 2.3229 - val_gamma_nll: 2.3227 - val_root_mean_squared_error: 2369.2183
# Epoch 86/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2765 - gamma_nll: 2.2773 - root_mean_squared_error: 2408.9688 - val_loss: 2.3400 - val_gamma_nll: 2.3399 - val_root_mean_squared_error: 2363.7910
# Epoch 87/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.3021 - gamma_nll: 2.3031 - root_mean_squared_error: 2408.0300 - val_loss: 2.3832 - val_gamma_nll: 2.3831 - val_root_mean_squared_error: 2421.1235
# Epoch 88/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2835 - gamma_nll: 2.2832 - root_mean_squared_error: 2408.8779 - val_loss: 2.3260 - val_gamma_nll: 2.3258 - val_root_mean_squared_error: 2379.7046
# Epoch 89/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2761 - gamma_nll: 2.2766 - root_mean_squared_error: 2406.4082 - val_loss: 2.3357 - val_gamma_nll: 2.3354 - val_root_mean_squared_error: 2357.1333
# Epoch 90/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.2858 - gamma_nll: 2.2857 - root_mean_squared_error: 2402.5312 - val_loss: 2.3086 - val_gamma_nll: 2.3084 - val_root_mean_squared_error: 2335.0557
# Epoch 91/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2887 - gamma_nll: 2.2884 - root_mean_squared_error: 2408.1855 - val_loss: 2.3231 - val_gamma_nll: 2.3230 - val_root_mean_squared_error: 2352.7271
# Epoch 92/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2765 - gamma_nll: 2.2762 - root_mean_squared_error: 2403.8167 - val_loss: 2.3373 - val_gamma_nll: 2.3375 - val_root_mean_squared_error: 2361.7703
# Epoch 93/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2766 - gamma_nll: 2.2759 - root_mean_squared_error: 2397.2241 - val_loss: 2.3247 - val_gamma_nll: 2.3248 - val_root_mean_squared_error: 2375.9893
# Epoch 94/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.2741 - gamma_nll: 2.2745 - root_mean_squared_error: 2396.8635 - val_loss: 2.3300 - val_gamma_nll: 2.3298 - val_root_mean_squared_error: 2364.3704
# Epoch 95/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2751 - gamma_nll: 2.2761 - root_mean_squared_error: 2398.8896 - val_loss: 2.3110 - val_gamma_nll: 2.3108 - val_root_mean_squared_error: 2332.5493
# Epoch 96/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.2846 - gamma_nll: 2.2834 - root_mean_squared_error: 2415.0466 - val_loss: 2.3140 - val_gamma_nll: 2.3140 - val_root_mean_squared_error: 2337.4260
# Epoch 97/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2693 - gamma_nll: 2.2691 - root_mean_squared_error: 2396.4983 - val_loss: 2.3606 - val_gamma_nll: 2.3603 - val_root_mean_squared_error: 2479.4116
# Epoch 98/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.2752 - gamma_nll: 2.2757 - root_mean_squared_error: 2400.1133 - val_loss: 2.3314 - val_gamma_nll: 2.3314 - val_root_mean_squared_error: 2375.6370
# Epoch 99/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2672 - gamma_nll: 2.2675 - root_mean_squared_error: 2406.3955 - val_loss: 2.3240 - val_gamma_nll: 2.3236 - val_root_mean_squared_error: 2349.7844
# Epoch 100/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.2833 - gamma_nll: 2.2833 - root_mean_squared_error: 2411.8208 - val_loss: 2.3042 - val_gamma_nll: 2.3038 - val_root_mean_squared_error: 2343.7610
# Epoch 101/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2668 - gamma_nll: 2.2671 - root_mean_squared_error: 2403.7358 - val_loss: 2.3187 - val_gamma_nll: 2.3187 - val_root_mean_squared_error: 2333.8499
# Epoch 102/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2646 - gamma_nll: 2.2642 - root_mean_squared_error: 2398.7178 - val_loss: 2.3679 - val_gamma_nll: 2.3677 - val_root_mean_squared_error: 2326.0471
# Epoch 103/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2719 - gamma_nll: 2.2725 - root_mean_squared_error: 2402.7644 - val_loss: 2.3473 - val_gamma_nll: 2.3474 - val_root_mean_squared_error: 2382.0183
# Epoch 104/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2713 - gamma_nll: 2.2708 - root_mean_squared_error: 2404.4146 - val_loss: 2.3297 - val_gamma_nll: 2.3295 - val_root_mean_squared_error: 2325.8855
# Epoch 105/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2611 - gamma_nll: 2.2607 - root_mean_squared_error: 2390.4839 - val_loss: 2.3920 - val_gamma_nll: 2.3916 - val_root_mean_squared_error: 2342.5173
# Epoch 106/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.2723 - gamma_nll: 2.2719 - root_mean_squared_error: 2397.1455 - val_loss: 2.3377 - val_gamma_nll: 2.3376 - val_root_mean_squared_error: 2324.7673
# Epoch 107/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2688 - gamma_nll: 2.2685 - root_mean_squared_error: 2402.9634 - val_loss: 2.3403 - val_gamma_nll: 2.3401 - val_root_mean_squared_error: 2320.6714
# Epoch 108/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2795 - gamma_nll: 2.2798 - root_mean_squared_error: 2402.5806 - val_loss: 2.4023 - val_gamma_nll: 2.4027 - val_root_mean_squared_error: 2328.4885
# Epoch 109/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.2773 - gamma_nll: 2.2772 - root_mean_squared_error: 2403.9448 - val_loss: 2.3432 - val_gamma_nll: 2.3431 - val_root_mean_squared_error: 2323.8667
# Epoch 110/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2612 - gamma_nll: 2.2622 - root_mean_squared_error: 2404.0715 - val_loss: 2.3702 - val_gamma_nll: 2.3701 - val_root_mean_squared_error: 2328.8486
# Epoch 111/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.2546 - gamma_nll: 2.2542 - root_mean_squared_error: 2396.0969 - val_loss: 2.3296 - val_gamma_nll: 2.3294 - val_root_mean_squared_error: 2335.4814
# Epoch 112/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.2603 - gamma_nll: 2.2603 - root_mean_squared_error: 2387.3311 - val_loss: 2.3478 - val_gamma_nll: 2.3481 - val_root_mean_squared_error: 2336.3782
# Epoch 113/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2687 - gamma_nll: 2.2692 - root_mean_squared_error: 2404.6768 - val_loss: 2.3084 - val_gamma_nll: 2.3080 - val_root_mean_squared_error: 2333.1638
# Epoch 114/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2553 - gamma_nll: 2.2542 - root_mean_squared_error: 2396.1990 - val_loss: 2.3135 - val_gamma_nll: 2.3135 - val_root_mean_squared_error: 2331.8381
# Epoch 115/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2779 - gamma_nll: 2.2778 - root_mean_squared_error: 2405.0364 - val_loss: 2.3283 - val_gamma_nll: 2.3284 - val_root_mean_squared_error: 2363.2451
# Epoch 116/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2748 - gamma_nll: 2.2745 - root_mean_squared_error: 2400.9927 - val_loss: 2.3261 - val_gamma_nll: 2.3264 - val_root_mean_squared_error: 2333.8540
# Epoch 117/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2703 - gamma_nll: 2.2699 - root_mean_squared_error: 2400.3091 - val_loss: 2.3492 - val_gamma_nll: 2.3487 - val_root_mean_squared_error: 2339.0146
# Epoch 118/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2638 - gamma_nll: 2.2637 - root_mean_squared_error: 2407.1562 - val_loss: 2.3077 - val_gamma_nll: 2.3076 - val_root_mean_squared_error: 2380.2991
# Epoch 119/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2632 - gamma_nll: 2.2630 - root_mean_squared_error: 2403.1965 - val_loss: 2.3444 - val_gamma_nll: 2.3445 - val_root_mean_squared_error: 2401.5034
# Epoch 120/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2813 - gamma_nll: 2.2810 - root_mean_squared_error: 2410.1409 - val_loss: 2.3085 - val_gamma_nll: 2.3082 - val_root_mean_squared_error: 2361.4182
# Epoch 121/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2648 - gamma_nll: 2.2660 - root_mean_squared_error: 2407.4436 - val_loss: 2.3214 - val_gamma_nll: 2.3212 - val_root_mean_squared_error: 2331.4661
# Epoch 122/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.2678 - gamma_nll: 2.2677 - root_mean_squared_error: 2405.1633 - val_loss: 2.3157 - val_gamma_nll: 2.3158 - val_root_mean_squared_error: 2341.4207
# Epoch 123/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.2528 - gamma_nll: 2.2522 - root_mean_squared_error: 2396.8489 - val_loss: 2.3218 - val_gamma_nll: 2.3215 - val_root_mean_squared_error: 2321.4006
# Epoch 124/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2568 - gamma_nll: 2.2571 - root_mean_squared_error: 2390.7229 - val_loss: 2.3263 - val_gamma_nll: 2.3258 - val_root_mean_squared_error: 2359.2290
# Epoch 125/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.2691 - gamma_nll: 2.2687 - root_mean_squared_error: 2398.5923 - val_loss: 2.3242 - val_gamma_nll: 2.3242 - val_root_mean_squared_error: 2333.1492
# 1/1 [==============================] - 0s 22ms/step - loss: 2.3042 - gamma_nll: 2.3042 - root_mean_squared_error: 2343.7610

# %%
# -------------------------- plot the validation loss --------------------------
# Convert interaction loss dictionary to a pandas DataFrame
interaction_df = pd.DataFrame(list(interaction_loss.items()), columns = ['Interaction_Pair', 'Validation_Loss'])

# Sort the DataFrame by Validation_Loss in increasing order
interaction_df = interaction_df.sort_values(by = 'Validation_Loss', ascending = True)

# for presentation, select top k effect
interaction_df = interaction_df.head(10)

# Create the bar plot using Seaborn
# plt.figure(figsize = (12, 8))
sns.lineplot(x = 'Interaction_Pair', y = 'Validation_Loss', data = interaction_df, marker = 'o')
plt.axhline(main_val_loss, color = 'red', linestyle = '--')
plt.xlabel('')
plt.ylabel('Validation Loss')
plt.title('Validation Loss for Pairwise Effect - Top 10 - Low Noise')
# plt.legend()

plt.rcParams["figure.figsize"] = (9, 3) # (for square figures)
plt.rcParams["figure.dpi"] = 350
plt.rcParams["savefig.bbox"] = "tight"
plt.rcParams["font.family"] = "serif"
plt.rcParams["axes.spines.right"] = False
plt.rcParams["axes.spines.top"] = False

plt.ylim(2.2,2.7)

plt.show()
